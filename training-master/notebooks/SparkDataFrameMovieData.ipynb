# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[1]")\
                            .appName("DFApp").getOrCreate()

# %%
from pyspark.sql.types import StructType, LongType,StringType, IntegerType, DoubleType

movieSchema = StructType()\
         .add("movieId", IntegerType(), True)\
         .add("title", StringType(), True)\
         .add("genres", StringType(), True)\


ratingSchema = StructType()\
         .add("userId", IntegerType(), True)\
         .add("movieId", IntegerType(), True)\
         .add("rating", DoubleType(), True)\
         .add("timestamp", StringType(), True)\

# %%
movieDf = spark.read.format("csv")\
          .option("header", True)\
          .schema(movieSchema)\
          .load("file:///c:/data/movies.csv")

ratingDf = spark.read.format("csv")\
          .option("header", True)\
          .schema(ratingSchema)\
          .load("file:///c:/data/ratings.csv")

# %%
movieDf.show(2)
ratingDf.show(2)
# Out:
# +-------+----------------+--------------------+
# |movieId|           title|              genres|
# +-------+----------------+--------------------+
# |      1|Toy Story (1995)|Adventure|Animati...|
# |      2|  Jumanji (1995)|Adventure|Childre...|
# +-------+----------------+--------------------+
# only showing top 2 rows
#
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# +------+-------+------+---------+
# only showing top 2 rows

# %%
# out of all 4 columns, we pick below 2 columns
df2 = ratingDf.select("movieId", "rating")
df2.show(2)
# Out:
# +-------+------+
# |movieId|rating|
# +-------+------+
# |      1|   4.0|
# |      3|   4.0|
# +-------+------+
# only showing top 2 rows

# %%
# count

print("Count ", ratingDf.count())
# Out:
# Count  100836

# %%
# to get all columns
print("Columns", ratingDf.columns)
# schema
print(ratingDf.schema)
# Out:
# Columns ['userId', 'movieId', 'rating', 'timestamp']
# StructType(List(StructField(userId,IntegerType,true),StructField(movieId,IntegerType,true),StructField(rating,DoubleType,true),StructField(timestamp,StringType,true)))

# %%
# create and return new dataframe with 2 columns movieId, rating
df3 = ratingDf.select("movieId", "rating")
df3.printSchema()
df3.show(2)
# Out:
# root
#  |-- movieId: integer (nullable = true)
#  |-- rating: double (nullable = true)
#
# +-------+------+
# |movieId|rating|
# +-------+------+
# |      1|   4.0|
# |      3|   4.0|
# +-------+------+
# only showing top 2 rows

# %%
movieDf.collect()
# Out:
# [Row(movieId=1, title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy'),
#  Row(movieId=2, title='Jumanji (1995)', genres='Adventure|Children|Fantasy'),
#  Row(movieId=3, title='Grumpier Old Men (1995)', genres='Comedy|Romance'),
#  Row(movieId=4, title='Waiting to Exhale (1995)', genres='Comedy|Drama|Romance'),
#  Row(movieId=5, title='Father of the Bride Part II (1995)', genres='Comedy'),
#  Row(movieId=6, title='Heat (1995)', genres='Action|Crime|Thriller'),
#  Row(movieId=7, title='Sabrina (1995)', genres='Comedy|Romance'),
#  Row(movieId=8, title='Tom and Huck (1995)', genres='Adventure|Children'),
#  Row(movieId=9, title='Sudden Death (1995)', genres='Action'),
#  Row(movieId=10, title='GoldenEye (1995)', genres='Action|Adventure|Thriller'),
#  Row(movieId=11, title='American President, The (1995)', genres='Comedy|Drama|Romance'),
#  Row(movieId=12, title='Dracula: Dead and Loving It (1995)', genres='Comedy|Horror'),
#  Row(movieId=13, title='Balto (1995)', genres='Adventure|Animation|Children'),
#  Row(movieId=14, title='Nixon (1995)', genres='Drama'),
#  Row(movieId=15, title='Cutthroat Island (1995)', genres='Action|Adventure|Romance'),
#  Row(movieId=16, title='Casino (1995)', genres='Crime|Drama'),
#  Row(movieId=17, title='Sense and Sensibility (1995)', genres='Drama|Romance'),
#  Row(movieId=18, title='Four Rooms (1995)', genres='Comedy'),
#  Row(movieId=19, title='Ace Ventura: When Nature Calls (1995)', genres='Comedy'),
#  Row(movieId=20, title='Money Train (1995)', genres='Action|Comedy|Crime|Drama|Thriller'),
#  Row(movieId=21, title='Get Shorty (1995)', genres='Comedy|Crime|Thriller'),
#  Row(movieId=22, title='Copycat (1995)', genres='Crime|Drama|Horror|Mystery|Thriller'),
#  Row(movieId=23, title='Assassins (1995)', genres='Action|Crime|Thriller'),
#  Row(movieId=24, title='Powder (1995)', genres='Drama|Sci-Fi'),
#  Row(movieId=25, title='Leaving Las Vegas (1995)', genres='Drama|Romance'),
#  Row(movieId=26, title='Othello (1995)', genres='Drama'),
#  Row(movieId=27, title='Now and Then (1995)', genres='Children|Drama'),
#  Row(movieId=28, title='Persuasion (1995)', genres='Drama|Romance'),
#  Row(movieId=29, title='City of Lost Children, The (Cité des enfants perdus, La) (1995)', genres='Adventure|Drama|Fantasy|Mystery|Sci-Fi'),
#  Row(movieId=30, title='Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)', genres='Crime|Drama'),
#  Row(movieId=31, title='Dangerous Minds (1995)', genres='Drama'),
#  Row(movieId=32, title='Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', genres='Mystery|Sci-Fi|Thriller'),
#  Row(movieId=34, title='Babe (1995)', genres='Children|Drama'),
#  Row(movieId=36, title='Dead Man Walking (1995)', genres='Crime|Drama'),
#  Row(movieId=38, title='It Takes Two (1995)', genres='Children|Comedy'),
#  Row(movieId=39, title='Clueless (1995)', genres='Comedy|Romance'),
#  Row(movieId=40, title='Cry, the Beloved Country (1995)', genres='Drama'),
#  Row(movieId=41, title='Richard III (1995)', genres='Drama|War'),
#  Row(movieId=42, title='Dead Presidents (1995)', genres='Action|Crime|Drama'),
#  Row(movieId=43, title='Restoration (1995)', genres='Drama'),
#  Row(movieId=44, title='Mortal Kombat (1995)', genres='Action|Adventure|Fantasy'),
#  Row(movieId=45, title='To Die For (1995)', genres='Comedy|Drama|Thriller'),
#  Row(movieId=46, title='How to Make an American Quilt (1995)', genres='Drama|Romance'),
#  Row(movieId=47, title='Seven (a.k.a. Se7en) (1995)', genres='Mystery|Thriller'),
#  Row(movieId=48, title='Pocahontas (1995)', genres='Animation|Children|Drama|Musical|Romance'),
#  Row(movieId=49, title='When Night Is Falling (1995)', genres='Drama|Romance'),
#  Row(movieId=50, title='Usual Suspects, The (1995)', genres='Crime|Mystery|Thriller'),
#  Row(movieId=52, title='Mighty Aphrodite (1995)', genres='Comedy|Drama|Romance'),
#  Row(movieId=53, title='Lamerica (1994)', genres='Adventure|Drama'),
#  Row(movieId=54, title='Big Green, The (1995)', genres='Children|Comedy'),
#  Row(movieId=55, title='Georgia (1995)', genres='Drama'),
#  Row(movieId=57, title='Home for the Holidays (1995)', genres='Drama'),
#  Row(movieId=58, title='Postman, The (Postino, Il) (1994)', genres='Comedy|Drama|Romance'),
#  Row(movieId=60, title='Indian in the Cupboard, The (1995)', genres='Adventure|Children|Fantasy'),
#  Row(movieId=61, title='Eye for an Eye (1996)', genres='Drama|Thriller'),
#  Row(movieId=62, title="Mr. Holland's Opus (1995)", genres='Drama'),
#  Row(movieId=63, title="Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996)", genres='Comedy|Crime'),
#  Row(movieId=64, title='Two if by Sea (1996)', genres='Comedy|Romance'),
#  Row(movieId=65, title='Bio-Dome (1996)', genres='Comedy'),
#  Row(movieId=66, title='Lawnmower Man 2: Beyond Cyberspace (1996)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=68, title='French Twist (Gazon maudit) (1995)', genres='Comedy|Romance'),
#  Row(movieId=69, title='Friday (1995)', genres='Comedy'),
#  Row(movieId=70, title='From Dusk Till Dawn (1996)', genres='Action|Comedy|Horror|Thriller'),
#  Row(movieId=71, title='Fair Game (1995)', genres='Action'),
#  Row(movieId=72, title='Kicking and Screaming (1995)', genres='Comedy|Drama'),
#  Row(movieId=73, title='Misérables, Les (1995)', genres='Drama|War'),
#  Row(movieId=74, title='Bed of Roses (1996)', genres='Drama|Romance'),
#  Row(movieId=75, title='Big Bully (1996)', genres='Comedy|Drama'),
#  Row(movieId=76, title='Screamers (1995)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=77, title='Nico Icon (1995)', genres='Documentary'),
#  Row(movieId=78, title='Crossing Guard, The (1995)', genres='Action|Crime|Drama|Thriller'),
#  Row(movieId=79, title='Juror, The (1996)', genres='Drama|Thriller'),
#  Row(movieId=80, title='White Balloon, The (Badkonake sefid) (1995)', genres='Children|Drama'),
#  Row(movieId=81, title="Things to Do in Denver When You're Dead (1995)", genres='Crime|Drama|Romance'),
#  Row(movieId=82, title="Antonia's Line (Antonia) (1995)", genres='Comedy|Drama'),
#  Row(movieId=83, title='Once Upon a Time... When We Were Colored (1995)', genres='Drama|Romance'),
#  Row(movieId=85, title='Angels and Insects (1995)', genres='Drama|Romance'),
#  Row(movieId=86, title='White Squall (1996)', genres='Action|Adventure|Drama'),
#  Row(movieId=87, title='Dunston Checks In (1996)', genres='Children|Comedy'),
#  Row(movieId=88, title='Black Sheep (1996)', genres='Comedy'),
#  Row(movieId=89, title='Nick of Time (1995)', genres='Action|Thriller'),
#  Row(movieId=92, title='Mary Reilly (1996)', genres='Drama|Horror|Thriller'),
#  Row(movieId=93, title='Vampire in Brooklyn (1995)', genres='Comedy|Horror|Romance'),
#  Row(movieId=94, title='Beautiful Girls (1996)', genres='Comedy|Drama|Romance'),
#  Row(movieId=95, title='Broken Arrow (1996)', genres='Action|Adventure|Thriller'),
#  Row(movieId=96, title='In the Bleak Midwinter (1995)', genres='Comedy|Drama'),
#  Row(movieId=97, title='Hate (Haine, La) (1995)', genres='Crime|Drama'),
#  Row(movieId=99, title='Heidi Fleiss: Hollywood Madam (1995)', genres='Documentary'),
#  Row(movieId=100, title='City Hall (1996)', genres='Drama|Thriller'),
#  Row(movieId=101, title='Bottle Rocket (1996)', genres='Adventure|Comedy|Crime|Romance'),
#  Row(movieId=102, title='Mr. Wrong (1996)', genres='Comedy'),
#  Row(movieId=103, title='Unforgettable (1996)', genres='Mystery|Sci-Fi|Thriller'),
#  Row(movieId=104, title='Happy Gilmore (1996)', genres='Comedy'),
#  Row(movieId=105, title='Bridges of Madison County, The (1995)', genres='Drama|Romance'),
#  Row(movieId=106, title='Nobody Loves Me (Keiner liebt mich) (1994)', genres='Comedy|Drama'),
#  Row(movieId=107, title='Muppet Treasure Island (1996)', genres='Adventure|Children|Comedy|Musical'),
#  Row(movieId=108, title='Catwalk (1996)', genres='Documentary'),
#  Row(movieId=110, title='Braveheart (1995)', genres='Action|Drama|War'),
#  Row(movieId=111, title='Taxi Driver (1976)', genres='Crime|Drama|Thriller'),
#  Row(movieId=112, title='Rumble in the Bronx (Hont faan kui) (1995)', genres='Action|Adventure|Comedy|Crime'),
#  Row(movieId=113, title='Before and After (1996)', genres='Drama|Mystery'),
#  Row(movieId=116, title='Anne Frank Remembered (1995)', genres='Documentary'),
#  Row(movieId=117, title="Young Poisoner's Handbook, The (1995)", genres='Crime|Drama'),
#  Row(movieId=118, title='If Lucy Fell (1996)', genres='Comedy|Romance'),
#  Row(movieId=119, title='Steal Big, Steal Little (1995)', genres='Comedy'),
#  Row(movieId=121, title='Boys of St. Vincent, The (1992)', genres='Drama'),
#  Row(movieId=122, title='Boomerang (1992)', genres='Comedy|Romance'),
#  Row(movieId=123, title='Chungking Express (Chung Hing sam lam) (1994)', genres='Drama|Mystery|Romance'),
#  Row(movieId=125, title='Flirting With Disaster (1996)', genres='Comedy'),
#  Row(movieId=126, title='NeverEnding Story III, The (1994)', genres='Adventure|Children|Fantasy'),
#  Row(movieId=128, title="Jupiter's Wife (1994)", genres='Documentary'),
#  Row(movieId=129, title='Pie in the Sky (1996)', genres='Comedy|Romance'),
#  Row(movieId=132, title='Jade (1995)', genres='Thriller'),
#  Row(movieId=135, title='Down Periscope (1996)', genres='Comedy'),
#  Row(movieId=137, title='Man of the Year (1995)', genres='Documentary'),
#  Row(movieId=140, title='Up Close and Personal (1996)', genres='Drama|Romance'),
#  Row(movieId=141, title='Birdcage, The (1996)', genres='Comedy'),
#  Row(movieId=144, title='Brothers McMullen, The (1995)', genres='Comedy'),
#  Row(movieId=145, title='Bad Boys (1995)', genres='Action|Comedy|Crime|Drama|Thriller'),
#  Row(movieId=146, title='Amazing Panda Adventure, The (1995)', genres='Adventure|Children'),
#  Row(movieId=147, title='Basketball Diaries, The (1995)', genres='Drama'),
#  Row(movieId=148, title='Awfully Big Adventure, An (1995)', genres='Drama'),
#  Row(movieId=149, title='Amateur (1994)', genres='Crime|Drama|Thriller'),
#  Row(movieId=150, title='Apollo 13 (1995)', genres='Adventure|Drama|IMAX'),
#  Row(movieId=151, title='Rob Roy (1995)', genres='Action|Drama|Romance|War'),
#  Row(movieId=152, title='Addiction, The (1995)', genres='Drama|Horror'),
#  Row(movieId=153, title='Batman Forever (1995)', genres='Action|Adventure|Comedy|Crime'),
#  Row(movieId=154, title='Beauty of the Day (Belle de jour) (1967)', genres='Drama'),
#  Row(movieId=155, title='Beyond Rangoon (1995)', genres='Adventure|Drama|War'),
#  Row(movieId=156, title='Blue in the Face (1995)', genres='Comedy|Drama'),
#  Row(movieId=157, title='Canadian Bacon (1995)', genres='Comedy|War'),
#  Row(movieId=158, title='Casper (1995)', genres='Adventure|Children'),
#  Row(movieId=159, title='Clockers (1995)', genres='Crime|Drama|Mystery'),
#  Row(movieId=160, title='Congo (1995)', genres='Action|Adventure|Mystery|Sci-Fi'),
#  Row(movieId=161, title='Crimson Tide (1995)', genres='Drama|Thriller|War'),
#  Row(movieId=162, title='Crumb (1994)', genres='Documentary'),
#  Row(movieId=163, title='Desperado (1995)', genres='Action|Romance|Western'),
#  Row(movieId=164, title='Devil in a Blue Dress (1995)', genres='Crime|Film-Noir|Mystery|Thriller'),
#  Row(movieId=165, title='Die Hard: With a Vengeance (1995)', genres='Action|Crime|Thriller'),
#  Row(movieId=166, title='Doom Generation, The (1995)', genres='Comedy|Crime|Drama'),
#  Row(movieId=168, title='First Knight (1995)', genres='Action|Drama|Romance'),
#  Row(movieId=169, title='Free Willy 2: The Adventure Home (1995)', genres='Adventure|Children|Drama'),
#  Row(movieId=170, title='Hackers (1995)', genres='Action|Adventure|Crime|Thriller'),
#  Row(movieId=171, title='Jeffrey (1995)', genres='Comedy|Drama'),
#  Row(movieId=172, title='Johnny Mnemonic (1995)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=173, title='Judge Dredd (1995)', genres='Action|Crime|Sci-Fi'),
#  Row(movieId=174, title='Jury Duty (1995)', genres='Comedy'),
#  Row(movieId=175, title='Kids (1995)', genres='Drama'),
#  Row(movieId=176, title='Living in Oblivion (1995)', genres='Comedy'),
#  Row(movieId=177, title='Lord of Illusions (1995)', genres='Horror'),
#  Row(movieId=178, title='Love & Human Remains (1993)', genres='Comedy|Drama'),
#  Row(movieId=179, title='Mad Love (1995)', genres='Drama|Romance'),
#  Row(movieId=180, title='Mallrats (1995)', genres='Comedy|Romance'),
#  Row(movieId=181, title='Mighty Morphin Power Rangers: The Movie (1995)', genres='Action|Children'),
#  Row(movieId=183, title='Mute Witness (1994)', genres='Comedy|Horror|Thriller'),
#  Row(movieId=184, title='Nadja (1994)', genres='Drama'),
#  Row(movieId=185, title='Net, The (1995)', genres='Action|Crime|Thriller'),
#  Row(movieId=186, title='Nine Months (1995)', genres='Comedy|Romance'),
#  Row(movieId=187, title='Party Girl (1995)', genres='Comedy'),
#  Row(movieId=188, title='Prophecy, The (1995)', genres='Fantasy|Horror|Mystery'),
#  Row(movieId=189, title='Reckless (1995)', genres='Comedy|Fantasy'),
#  Row(movieId=190, title='Safe (1995)', genres='Thriller'),
#  Row(movieId=191, title='Scarlet Letter, The (1995)', genres='Drama|Romance'),
#  Row(movieId=193, title='Showgirls (1995)', genres='Drama'),
#  Row(movieId=194, title='Smoke (1995)', genres='Comedy|Drama'),
#  Row(movieId=195, title='Something to Talk About (1995)', genres='Comedy|Drama|Romance'),
#  Row(movieId=196, title='Species (1995)', genres='Horror|Sci-Fi'),
#  Row(movieId=198, title='Strange Days (1995)', genres='Action|Crime|Drama|Mystery|Sci-Fi|Thriller'),
#  Row(movieId=199, title='Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964)', genres='Drama|Musical|Romance'),
#  Row(movieId=201, title='Three Wishes (1995)', genres='Drama|Fantasy'),
#  Row(movieId=202, title='Total Eclipse (1995)', genres='Drama|Romance'),
#  Row(movieId=203, title='To Wong Foo, Thanks for Everything! Julie Newmar (1995)', genres='Comedy'),
#  Row(movieId=204, title='Under Siege 2: Dark Territory (1995)', genres='Action'),
#  Row(movieId=205, title='Unstrung Heroes (1995)', genres='Comedy|Drama'),
#  Row(movieId=206, title='Unzipped (1995)', genres='Documentary'),
#  Row(movieId=207, title='Walk in the Clouds, A (1995)', genres='Drama|Romance'),
#  Row(movieId=208, title='Waterworld (1995)', genres='Action|Adventure|Sci-Fi'),
#  Row(movieId=209, title="White Man's Burden (1995)", genres='Drama'),
#  Row(movieId=210, title='Wild Bill (1995)', genres='Western'),
#  Row(movieId=211, title='Browning Version, The (1994)', genres='Drama'),
#  Row(movieId=212, title='Bushwhacked (1995)', genres='Adventure|Comedy|Crime|Mystery'),
#  Row(movieId=213, title='Burnt by the Sun (Utomlyonnye solntsem) (1994)', genres='Drama'),
#  Row(movieId=214, title='Before the Rain (Pred dozhdot) (1994)', genres='Drama|War'),
#  Row(movieId=215, title='Before Sunrise (1995)', genres='Drama|Romance'),
#  Row(movieId=216, title='Billy Madison (1995)', genres='Comedy'),
#  Row(movieId=217, title='Babysitter, The (1995)', genres='Drama|Thriller'),
#  Row(movieId=218, title='Boys on the Side (1995)', genres='Comedy|Drama'),
#  Row(movieId=219, title='Cure, The (1995)', genres='Drama'),
#  Row(movieId=220, title='Castle Freak (1995)', genres='Horror'),
#  Row(movieId=222, title='Circle of Friends (1995)', genres='Drama|Romance'),
#  Row(movieId=223, title='Clerks (1994)', genres='Comedy'),
#  Row(movieId=224, title='Don Juan DeMarco (1995)', genres='Comedy|Drama|Romance'),
#  Row(movieId=225, title='Disclosure (1994)', genres='Drama|Thriller'),
#  Row(movieId=227, title='Drop Zone (1994)', genres='Action|Thriller'),
#  Row(movieId=228, title='Destiny Turns on the Radio (1995)', genres='Comedy'),
#  Row(movieId=229, title='Death and the Maiden (1994)', genres='Drama|Thriller'),
#  Row(movieId=230, title='Dolores Claiborne (1995)', genres='Drama|Thriller'),
#  Row(movieId=231, title='Dumb & Dumber (Dumb and Dumber) (1994)', genres='Adventure|Comedy'),
#  Row(movieId=232, title='Eat Drink Man Woman (Yin shi nan nu) (1994)', genres='Comedy|Drama|Romance'),
#  Row(movieId=233, title='Exotica (1994)', genres='Drama'),
#  Row(movieId=234, title='Exit to Eden (1994)', genres='Comedy'),
#  Row(movieId=235, title='Ed Wood (1994)', genres='Comedy|Drama'),
#  Row(movieId=236, title='French Kiss (1995)', genres='Action|Comedy|Romance'),
#  Row(movieId=237, title='Forget Paris (1995)', genres='Comedy|Romance'),
#  Row(movieId=238, title='Far From Home: The Adventures of Yellow Dog (1995)', genres='Adventure|Children'),
#  Row(movieId=239, title='Goofy Movie, A (1995)', genres='Animation|Children|Comedy|Romance'),
#  Row(movieId=240, title='Hideaway (1995)', genres='Thriller'),
#  Row(movieId=241, title='Fluke (1995)', genres='Children|Drama'),
#  Row(movieId=242, title='Farinelli: il castrato (1994)', genres='Drama|Musical'),
#  Row(movieId=243, title='Gordy (1995)', genres='Children|Comedy|Fantasy'),
#  Row(movieId=246, title='Hoop Dreams (1994)', genres='Documentary'),
#  Row(movieId=247, title='Heavenly Creatures (1994)', genres='Crime|Drama'),
#  Row(movieId=248, title='Houseguest (1994)', genres='Comedy'),
#  Row(movieId=249, title='Immortal Beloved (1994)', genres='Drama|Romance'),
#  Row(movieId=250, title='Heavyweights (Heavy Weights) (1995)', genres='Children|Comedy'),
#  Row(movieId=251, title='Hunted, The (1995)', genres='Action'),
#  Row(movieId=252, title='I.Q. (1994)', genres='Comedy|Romance'),
#  Row(movieId=253, title='Interview with the Vampire: The Vampire Chronicles (1994)', genres='Drama|Horror'),
#  Row(movieId=254, title='Jefferson in Paris (1995)', genres='Drama'),
#  Row(movieId=255, title='Jerky Boys, The (1995)', genres='Comedy'),
#  Row(movieId=256, title='Junior (1994)', genres='Comedy|Sci-Fi'),
#  Row(movieId=257, title='Just Cause (1995)', genres='Mystery|Thriller'),
#  Row(movieId=258, title="Kid in King Arthur's Court, A (1995)", genres='Adventure|Children|Comedy|Fantasy|Romance'),
#  Row(movieId=259, title='Kiss of Death (1995)', genres='Crime|Drama|Thriller'),
#  Row(movieId=260, title='Star Wars: Episode IV - A New Hope (1977)', genres='Action|Adventure|Sci-Fi'),
#  Row(movieId=261, title='Little Women (1994)', genres='Drama'),
#  Row(movieId=262, title='Little Princess, A (1995)', genres='Children|Drama'),
#  Row(movieId=263, title='Ladybird Ladybird (1994)', genres='Drama'),
#  Row(movieId=265, title='Like Water for Chocolate (Como agua para chocolate) (1992)', genres='Drama|Fantasy|Romance'),
#  Row(movieId=266, title='Legends of the Fall (1994)', genres='Drama|Romance|War|Western'),
#  Row(movieId=267, title='Major Payne (1995)', genres='Comedy'),
#  Row(movieId=269, title='My Crazy Life (Mi vida loca) (1993)', genres='Drama'),
#  Row(movieId=270, title='Love Affair (1994)', genres='Drama|Romance'),
#  Row(movieId=271, title='Losing Isaiah (1995)', genres='Drama'),
#  Row(movieId=272, title='Madness of King George, The (1994)', genres='Comedy|Drama'),
#  Row(movieId=273, title="Mary Shelley's Frankenstein (Frankenstein) (1994)", genres='Drama|Horror|Sci-Fi'),
#  Row(movieId=274, title='Man of the House (1995)', genres='Comedy'),
#  Row(movieId=275, title='Mixed Nuts (1994)', genres='Comedy'),
#  Row(movieId=276, title='Milk Money (1994)', genres='Comedy|Romance'),
#  Row(movieId=277, title='Miracle on 34th Street (1994)', genres='Drama'),
#  Row(movieId=278, title='Miami Rhapsody (1995)', genres='Comedy'),
#  Row(movieId=279, title='My Family (1995)', genres='Drama'),
#  Row(movieId=280, title='Murder in the First (1995)', genres='Drama|Thriller'),
#  Row(movieId=281, title="Nobody's Fool (1994)", genres='Comedy|Drama|Romance'),
#  Row(movieId=282, title='Nell (1994)', genres='Drama'),
#  Row(movieId=283, title='New Jersey Drive (1995)', genres='Crime|Drama'),
#  Row(movieId=284, title='New York Cop (Nyû Yôku no koppu) (1993)', genres='Action|Crime'),
#  Row(movieId=285, title='Beyond Bedlam (1993)', genres='Drama|Horror'),
#  Row(movieId=287, title='Nina Takes a Lover (1994)', genres='Comedy|Romance'),
#  Row(movieId=288, title='Natural Born Killers (1994)', genres='Action|Crime|Thriller'),
#  Row(movieId=289, title='Only You (1994)', genres='Comedy|Romance'),
#  Row(movieId=290, title='Once Were Warriors (1994)', genres='Crime|Drama'),
#  Row(movieId=291, title='Poison Ivy II (1996)', genres='Drama|Thriller'),
#  Row(movieId=292, title='Outbreak (1995)', genres='Action|Drama|Sci-Fi|Thriller'),
#  Row(movieId=293, title='Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', genres='Action|Crime|Drama|Thriller'),
#  Row(movieId=294, title='Perez Family, The (1995)', genres='Comedy|Romance'),
#  Row(movieId=295, title="Pyromaniac's Love Story, A (1995)", genres='Comedy|Romance'),
#  Row(movieId=296, title='Pulp Fiction (1994)', genres='Comedy|Crime|Drama|Thriller'),
#  Row(movieId=298, title='Pushing Hands (Tui shou) (1992)', genres='Drama'),
#  Row(movieId=299, title='Priest (1994)', genres='Drama'),
#  Row(movieId=300, title='Quiz Show (1994)', genres='Drama'),
#  Row(movieId=301, title='Picture Bride (Bijo photo) (1994)', genres='Drama|Romance'),
#  Row(movieId=302, title='Queen Margot (Reine Margot, La) (1994)', genres='Drama|Romance'),
#  Row(movieId=303, title='Quick and the Dead, The (1995)', genres='Action|Thriller|Western'),
#  Row(movieId=304, title='Roommates (1995)', genres='Comedy|Drama'),
#  Row(movieId=305, title='Ready to Wear (Pret-A-Porter) (1994)', genres='Comedy'),
#  Row(movieId=306, title='Three Colors: Red (Trois couleurs: Rouge) (1994)', genres='Drama'),
#  Row(movieId=307, title='Three Colors: Blue (Trois couleurs: Bleu) (1993)', genres='Drama'),
#  Row(movieId=308, title='Three Colors: White (Trzy kolory: Bialy) (1994)', genres='Comedy|Drama'),
#  Row(movieId=310, title='Rent-a-Kid (1995)', genres='Comedy'),
#  Row(movieId=311, title='Relative Fear (1994)', genres='Horror|Thriller'),
#  Row(movieId=312, title='Stuart Saves His Family (1995)', genres='Comedy'),
#  Row(movieId=313, title='Swan Princess, The (1994)', genres='Animation|Children'),
#  Row(movieId=314, title='Secret of Roan Inish, The (1994)', genres='Children|Drama|Fantasy|Mystery'),
#  Row(movieId=315, title='Specialist, The (1994)', genres='Action|Drama|Thriller'),
#  Row(movieId=316, title='Stargate (1994)', genres='Action|Adventure|Sci-Fi'),
#  Row(movieId=317, title='Santa Clause, The (1994)', genres='Comedy|Drama|Fantasy'),
#  Row(movieId=318, title='Shawshank Redemption, The (1994)', genres='Crime|Drama'),
#  Row(movieId=319, title='Shallow Grave (1994)', genres='Comedy|Drama|Thriller'),
#  Row(movieId=320, title='Suture (1993)', genres='Film-Noir|Thriller'),
#  Row(movieId=321, title='Strawberry and Chocolate (Fresa y chocolate) (1993)', genres='Drama'),
#  Row(movieId=322, title='Swimming with Sharks (1995)', genres='Comedy|Drama'),
#  Row(movieId=324, title='Sum of Us, The (1994)', genres='Comedy|Drama'),
#  Row(movieId=325, title="National Lampoon's Senior Trip (1995)", genres='Comedy'),
#  Row(movieId=326, title='To Live (Huozhe) (1994)', genres='Drama'),
#  Row(movieId=327, title='Tank Girl (1995)', genres='Action|Comedy|Sci-Fi'),
#  Row(movieId=328, title='Tales from the Crypt Presents: Demon Knight (1995)', genres='Horror|Thriller'),
#  Row(movieId=329, title='Star Trek: Generations (1994)', genres='Adventure|Drama|Sci-Fi'),
#  Row(movieId=330, title='Tales from the Hood (1995)', genres='Action|Crime|Horror'),
#  Row(movieId=331, title='Tom & Viv (1994)', genres='Drama'),
#  Row(movieId=332, title='Village of the Damned (1995)', genres='Horror|Sci-Fi'),
#  Row(movieId=333, title='Tommy Boy (1995)', genres='Comedy'),
#  Row(movieId=334, title='Vanya on 42nd Street (1994)', genres='Drama'),
#  Row(movieId=335, title='Underneath (1995)', genres='Mystery|Thriller'),
#  Row(movieId=336, title='Walking Dead, The (1995)', genres='Drama|War'),
#  Row(movieId=337, title="What's Eating Gilbert Grape (1993)", genres='Drama'),
#  Row(movieId=338, title='Virtuosity (1995)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=339, title='While You Were Sleeping (1995)', genres='Comedy|Romance'),
#  Row(movieId=340, title='War, The (1994)', genres='Adventure|Drama|War'),
#  Row(movieId=341, title='Double Happiness (1994)', genres='Drama'),
#  Row(movieId=342, title="Muriel's Wedding (1994)", genres='Comedy'),
#  Row(movieId=343, title='Baby-Sitters Club, The (1995)', genres='Children'),
#  Row(movieId=344, title='Ace Ventura: Pet Detective (1994)', genres='Comedy'),
#  Row(movieId=345, title='Adventures of Priscilla, Queen of the Desert, The (1994)', genres='Comedy|Drama'),
#  Row(movieId=346, title='Backbeat (1993)', genres='Drama|Musical'),
#  Row(movieId=347, title='Bitter Moon (1992)', genres='Drama|Film-Noir|Romance'),
#  Row(movieId=348, title='Bullets Over Broadway (1994)', genres='Comedy'),
#  Row(movieId=349, title='Clear and Present Danger (1994)', genres='Action|Crime|Drama|Thriller'),
#  Row(movieId=350, title='Client, The (1994)', genres='Drama|Mystery|Thriller'),
#  Row(movieId=351, title='Corrina, Corrina (1994)', genres='Comedy|Drama|Romance'),
#  Row(movieId=352, title='Crooklyn (1994)', genres='Comedy|Drama'),
#  Row(movieId=353, title='Crow, The (1994)', genres='Action|Crime|Fantasy|Thriller'),
#  Row(movieId=354, title='Cobb (1994)', genres='Drama'),
#  Row(movieId=355, title='Flintstones, The (1994)', genres='Children|Comedy|Fantasy'),
#  Row(movieId=356, title='Forrest Gump (1994)', genres='Comedy|Drama|Romance|War'),
#  Row(movieId=357, title='Four Weddings and a Funeral (1994)', genres='Comedy|Romance'),
#  Row(movieId=358, title='Higher Learning (1995)', genres='Drama'),
#  Row(movieId=359, title='I Like It Like That (1994)', genres='Comedy|Drama|Romance'),
#  Row(movieId=360, title='I Love Trouble (1994)', genres='Action|Comedy'),
#  Row(movieId=361, title='It Could Happen to You (1994)', genres='Comedy|Drama|Romance'),
#  Row(movieId=362, title='Jungle Book, The (1994)', genres='Adventure|Children|Romance'),
#  Row(movieId=363, title='Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993)', genres='Documentary'),
#  Row(movieId=364, title='Lion King, The (1994)', genres='Adventure|Animation|Children|Drama|Musical|IMAX'),
#  Row(movieId=365, title='Little Buddha (1993)', genres='Drama'),
#  Row(movieId=366, title="Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994)", genres='Drama|Horror|Mystery|Thriller'),
#  Row(movieId=367, title='Mask, The (1994)', genres='Action|Comedy|Crime|Fantasy'),
#  Row(movieId=368, title='Maverick (1994)', genres='Adventure|Comedy|Western'),
#  Row(movieId=369, title='Mrs. Parker and the Vicious Circle (1994)', genres='Drama'),
#  Row(movieId=370, title='Naked Gun 33 1/3: The Final Insult (1994)', genres='Action|Comedy'),
#  Row(movieId=371, title='Paper, The (1994)', genres='Comedy|Drama'),
#  Row(movieId=372, title='Reality Bites (1994)', genres='Comedy|Drama|Romance'),
#  Row(movieId=373, title='Red Rock West (1992)', genres='Thriller'),
#  Row(movieId=374, title='Richie Rich (1994)', genres='Children|Comedy'),
#  Row(movieId=376, title='River Wild, The (1994)', genres='Action|Thriller'),
#  Row(movieId=377, title='Speed (1994)', genres='Action|Romance|Thriller'),
#  Row(movieId=378, title='Speechless (1994)', genres='Comedy|Romance'),
#  Row(movieId=379, title='Timecop (1994)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=380, title='True Lies (1994)', genres='Action|Adventure|Comedy|Romance|Thriller'),
#  Row(movieId=381, title='When a Man Loves a Woman (1994)', genres='Drama|Romance'),
#  Row(movieId=382, title='Wolf (1994)', genres='Drama|Horror|Romance|Thriller'),
#  Row(movieId=383, title='Wyatt Earp (1994)', genres='Western'),
#  Row(movieId=384, title='Bad Company (1995)', genres='Action|Crime|Drama'),
#  Row(movieId=385, title='Man of No Importance, A (1994)', genres='Drama'),
#  Row(movieId=386, title='S.F.W. (1994)', genres='Drama'),
#  Row(movieId=387, title='Low Down Dirty Shame, A (1994)', genres='Action|Comedy'),
#  Row(movieId=388, title='Boys Life (1995)', genres='Drama'),
#  Row(movieId=389, title='Colonel Chabert, Le (1994)', genres='Drama|Romance|War'),
#  Row(movieId=390, title='Faster Pussycat! Kill! Kill! (1965)', genres='Action|Crime|Drama'),
#  Row(movieId=391, title="Jason's Lyric (1994)", genres='Crime|Drama'),
#  Row(movieId=393, title='Street Fighter (1994)', genres='Action|Adventure|Fantasy'),
#  Row(movieId=405, title='Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)', genres='Action|Fantasy'),
#  Row(movieId=406, title='Federal Hill (1994)', genres='Drama'),
#  Row(movieId=407, title='In the Mouth of Madness (1995)', genres='Horror|Thriller'),
#  Row(movieId=408, title='8 Seconds (1994)', genres='Drama'),
#  Row(movieId=409, title='Above the Rim (1994)', genres='Crime|Drama'),
#  Row(movieId=410, title='Addams Family Values (1993)', genres='Children|Comedy|Fantasy'),
#  Row(movieId=412, title='Age of Innocence, The (1993)', genres='Drama'),
#  Row(movieId=413, title='Airheads (1994)', genres='Comedy'),
#  Row(movieId=414, title='Air Up There, The (1994)', genres='Comedy'),
#  Row(movieId=415, title='Another Stakeout (1993)', genres='Comedy|Thriller'),
#  Row(movieId=416, title='Bad Girls (1994)', genres='Western'),
#  Row(movieId=417, title='Barcelona (1994)', genres='Comedy|Romance'),
#  Row(movieId=418, title='Being Human (1993)', genres='Drama'),
#  Row(movieId=419, title='Beverly Hillbillies, The (1993)', genres='Comedy'),
#  Row(movieId=420, title='Beverly Hills Cop III (1994)', genres='Action|Comedy|Crime|Thriller'),
#  Row(movieId=421, title='Black Beauty (1994)', genres='Adventure|Children|Drama'),
#  Row(movieId=422, title='Blink (1994)', genres='Thriller'),
#  Row(movieId=423, title='Blown Away (1994)', genres='Action|Thriller'),
#  Row(movieId=424, title='Blue Chips (1994)', genres='Drama'),
#  Row(movieId=425, title='Blue Sky (1994)', genres='Drama|Romance'),
#  Row(movieId=426, title='Body Snatchers (1993)', genres='Horror|Sci-Fi|Thriller'),
#  Row(movieId=427, title='Boxing Helena (1993)', genres='Drama|Mystery|Romance|Thriller'),
#  Row(movieId=428, title='Bronx Tale, A (1993)', genres='Drama'),
#  Row(movieId=429, title='Cabin Boy (1994)', genres='Comedy'),
#  Row(movieId=430, title='Calendar Girl (1993)', genres='Comedy|Drama'),
#  Row(movieId=431, title="Carlito's Way (1993)", genres='Crime|Drama'),
#  Row(movieId=432, title="City Slickers II: The Legend of Curly's Gold (1994)", genres='Adventure|Comedy|Western'),
#  Row(movieId=433, title='Clean Slate (1994)', genres='Comedy'),
#  Row(movieId=434, title='Cliffhanger (1993)', genres='Action|Adventure|Thriller'),
#  Row(movieId=435, title='Coneheads (1993)', genres='Comedy|Sci-Fi'),
#  Row(movieId=436, title='Color of Night (1994)', genres='Drama|Thriller'),
#  Row(movieId=437, title='Cops and Robbersons (1994)', genres='Comedy'),
#  Row(movieId=438, title='Cowboy Way, The (1994)', genres='Action|Comedy|Drama'),
#  Row(movieId=440, title='Dave (1993)', genres='Comedy|Romance'),
#  Row(movieId=441, title='Dazed and Confused (1993)', genres='Comedy'),
#  Row(movieId=442, title='Demolition Man (1993)', genres='Action|Adventure|Sci-Fi'),
#  Row(movieId=444, title='Even Cowgirls Get the Blues (1993)', genres='Comedy|Romance'),
#  Row(movieId=445, title='Fatal Instinct (1993)', genres='Comedy'),
#  Row(movieId=446, title='Farewell My Concubine (Ba wang bie ji) (1993)', genres='Drama|Romance'),
#  Row(movieId=448, title='Fearless (1993)', genres='Drama'),
#  Row(movieId=449, title='Fear of a Black Hat (1994)', genres='Comedy'),
#  Row(movieId=450, title='With Honors (1994)', genres='Comedy|Drama'),
#  Row(movieId=451, title='Flesh and Bone (1993)', genres='Drama|Mystery|Romance'),
#  Row(movieId=452, title="Widows' Peak (1994)", genres='Drama'),
#  Row(movieId=453, title='For Love or Money (1993)', genres='Comedy|Romance'),
#  Row(movieId=454, title='Firm, The (1993)', genres='Drama|Thriller'),
#  Row(movieId=455, title='Free Willy (1993)', genres='Adventure|Children|Drama'),
#  Row(movieId=456, title='Fresh (1994)', genres='Crime|Drama|Thriller'),
#  Row(movieId=457, title='Fugitive, The (1993)', genres='Thriller'),
#  Row(movieId=458, title='Geronimo: An American Legend (1993)', genres='Drama|Western'),
#  Row(movieId=459, title='Getaway, The (1994)', genres='Action|Adventure|Crime|Drama|Romance|Thriller'),
#  Row(movieId=460, title='Getting Even with Dad (1994)', genres='Comedy'),
#  Row(movieId=461, title='Go Fish (1994)', genres='Drama|Romance'),
#  Row(movieId=464, title='Hard Target (1993)', genres='Action|Adventure|Crime|Thriller'),
#  Row(movieId=466, title='Hot Shots! Part Deux (1993)', genres='Action|Comedy|War'),
#  Row(movieId=467, title='Live Nude Girls (1995)', genres='Comedy'),
#  Row(movieId=468, title='Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)', genres='Comedy|Romance'),
#  Row(movieId=469, title='House of the Spirits, The (1993)', genres='Drama|Romance'),
#  Row(movieId=470, title='House Party 3 (1994)', genres='Comedy'),
#  Row(movieId=471, title='Hudsucker Proxy, The (1994)', genres='Comedy'),
#  Row(movieId=472, title="I'll Do Anything (1994)", genres='Comedy|Drama'),
#  Row(movieId=473, title='In the Army Now (1994)', genres='Comedy|War'),
#  Row(movieId=474, title='In the Line of Fire (1993)', genres='Action|Thriller'),
#  Row(movieId=475, title='In the Name of the Father (1993)', genres='Drama'),
#  Row(movieId=476, title='Inkwell, The (1994)', genres='Comedy|Drama'),
#  Row(movieId=477, title="What's Love Got to Do with It? (1993)", genres='Drama|Musical'),
#  Row(movieId=478, title='Jimmy Hollywood (1994)', genres='Comedy|Crime|Drama'),
#  Row(movieId=479, title='Judgment Night (1993)', genres='Action|Crime|Thriller'),
#  Row(movieId=480, title='Jurassic Park (1993)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(movieId=481, title='Kalifornia (1993)', genres='Drama|Thriller'),
#  Row(movieId=482, title='Killing Zoe (1994)', genres='Crime|Drama|Thriller'),
#  Row(movieId=484, title='Lassie (1994)', genres='Adventure|Children'),
#  Row(movieId=485, title='Last Action Hero (1993)', genres='Action|Adventure|Comedy|Fantasy'),
#  Row(movieId=486, title='Life with Mikey (1993)', genres='Comedy'),
#  Row(movieId=487, title='Lightning Jack (1994)', genres='Comedy|Western'),
#  Row(movieId=488, title='M. Butterfly (1993)', genres='Drama|Romance'),
#  Row(movieId=489, title='Made in America (1993)', genres='Comedy'),
#  Row(movieId=490, title='Malice (1993)', genres='Thriller'),
#  Row(movieId=491, title='Man Without a Face, The (1993)', genres='Drama'),
#  Row(movieId=492, title='Manhattan Murder Mystery (1993)', genres='Comedy|Mystery'),
#  Row(movieId=493, title='Menace II Society (1993)', genres='Action|Crime|Drama'),
#  Row(movieId=494, title='Executive Decision (1996)', genres='Action|Adventure|Thriller'),
#  Row(movieId=495, title='In the Realm of the Senses (Ai no corrida) (1976)', genres='Drama'),
#  Row(movieId=496, title='What Happened Was... (1994)', genres='Comedy|Drama|Romance|Thriller'),
#  Row(movieId=497, title='Much Ado About Nothing (1993)', genres='Comedy|Romance'),
#  Row(movieId=499, title='Mr. Wonderful (1993)', genres='Comedy|Romance'),
#  Row(movieId=500, title='Mrs. Doubtfire (1993)', genres='Comedy|Drama'),
#  Row(movieId=501, title='Naked (1993)', genres='Drama'),
#  Row(movieId=502, title='Next Karate Kid, The (1994)', genres='Action|Children|Romance'),
#  Row(movieId=504, title='No Escape (1994)', genres='Action|Drama|Sci-Fi'),
#  Row(movieId=505, title='North (1994)', genres='Comedy'),
#  Row(movieId=506, title='Orlando (1992)', genres='Drama|Fantasy|Romance'),
#  Row(movieId=507, title='Perfect World, A (1993)', genres='Crime|Drama|Thriller'),
#  Row(movieId=508, title='Philadelphia (1993)', genres='Drama'),
#  Row(movieId=509, title='Piano, The (1993)', genres='Drama|Romance'),
#  Row(movieId=510, title='Poetic Justice (1993)', genres='Drama'),
#  Row(movieId=511, title='Program, The (1993)', genres='Action|Drama'),
#  Row(movieId=512, title='Puppet Masters, The (1994)', genres='Horror|Sci-Fi'),
#  Row(movieId=513, title='Radioland Murders (1994)', genres='Comedy|Mystery|Romance'),
#  Row(movieId=514, title='Ref, The (1994)', genres='Comedy'),
#  Row(movieId=515, title='Remains of the Day, The (1993)', genres='Drama|Romance'),
#  Row(movieId=516, title='Renaissance Man (1994)', genres='Comedy|Drama'),
#  Row(movieId=517, title='Rising Sun (1993)', genres='Action|Drama|Mystery'),
#  Row(movieId=518, title='Road to Wellville, The (1994)', genres='Comedy'),
#  Row(movieId=519, title='RoboCop 3 (1993)', genres='Action|Crime|Drama|Sci-Fi|Thriller'),
#  Row(movieId=520, title='Robin Hood: Men in Tights (1993)', genres='Comedy'),
#  Row(movieId=521, title='Romeo Is Bleeding (1993)', genres='Crime|Thriller'),
#  Row(movieId=522, title='Romper Stomper (1992)', genres='Action|Drama'),
#  Row(movieId=523, title='Ruby in Paradise (1993)', genres='Drama'),
#  Row(movieId=524, title='Rudy (1993)', genres='Drama'),
#  Row(movieId=526, title='Savage Nights (Nuits fauves, Les) (1992)', genres='Drama'),
#  Row(movieId=527, title="Schindler's List (1993)", genres='Drama|War'),
#  Row(movieId=528, title='Scout, The (1994)', genres='Comedy|Drama'),
#  Row(movieId=529, title='Searching for Bobby Fischer (1993)', genres='Drama'),
#  Row(movieId=531, title='Secret Garden, The (1993)', genres='Children|Drama'),
#  Row(movieId=532, title='Serial Mom (1994)', genres='Comedy|Crime|Horror'),
#  Row(movieId=533, title='Shadow, The (1994)', genres='Action|Adventure|Fantasy|Mystery'),
#  Row(movieId=534, title='Shadowlands (1993)', genres='Drama|Romance'),
#  Row(movieId=535, title='Short Cuts (1993)', genres='Drama'),
#  Row(movieId=536, title='Simple Twist of Fate, A (1994)', genres='Drama'),
#  Row(movieId=537, title='Sirens (1994)', genres='Drama'),
#  Row(movieId=538, title='Six Degrees of Separation (1993)', genres='Drama'),
#  Row(movieId=539, title='Sleepless in Seattle (1993)', genres='Comedy|Drama|Romance'),
#  Row(movieId=540, title='Sliver (1993)', genres='Thriller'),
#  Row(movieId=541, title='Blade Runner (1982)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=542, title='Son in Law (1993)', genres='Comedy|Drama|Romance'),
#  Row(movieId=543, title='So I Married an Axe Murderer (1993)', genres='Comedy|Romance|Thriller'),
#  Row(movieId=544, title='Striking Distance (1993)', genres='Action|Crime'),
#  Row(movieId=546, title='Super Mario Bros. (1993)', genres='Action|Adventure|Children|Comedy|Fantasy|Sci-Fi'),
#  Row(movieId=547, title='Surviving the Game (1994)', genres='Action|Adventure|Thriller'),
#  Row(movieId=548, title='Terminal Velocity (1994)', genres='Action|Mystery|Thriller'),
#  Row(movieId=549, title='Thirty-Two Short Films About Glenn Gould (1993)', genres='Drama|Musical'),
#  Row(movieId=550, title='Threesome (1994)', genres='Comedy|Romance'),
#  Row(movieId=551, title='Nightmare Before Christmas, The (1993)', genres='Animation|Children|Fantasy|Musical'),
#  Row(movieId=552, title='Three Musketeers, The (1993)', genres='Action|Adventure|Comedy|Romance'),
#  Row(movieId=553, title='Tombstone (1993)', genres='Action|Drama|Western'),
#  Row(movieId=555, title='True Romance (1993)', genres='Crime|Thriller'),
#  Row(movieId=556, title='War Room, The (1993)', genres='Documentary'),
#  Row(movieId=558, title='Pagemaster, The (1994)', genres='Action|Adventure|Animation|Children|Fantasy'),
#  Row(movieId=562, title='Welcome to the Dollhouse (1995)', genres='Comedy|Drama'),
#  Row(movieId=563, title='Germinal (1993)', genres='Drama|Romance'),
#  Row(movieId=564, title='Chasers (1994)', genres='Comedy'),
#  Row(movieId=567, title='Kika (1993)', genres='Comedy|Drama'),
#  Row(movieId=568, title='Bhaji on the Beach (1993)', genres='Comedy|Drama'),
#  Row(movieId=569, title='Little Big League (1994)', genres='Comedy|Drama'),
#  Row(movieId=573, title='Ciao, Professore! (Io speriamo che me la cavo) (1992)', genres='Drama'),
#  Row(movieId=574, title='Spanking the Monkey (1994)', genres='Comedy|Drama'),
#  Row(movieId=575, title='Little Rascals, The (1994)', genres='Children|Comedy'),
#  Row(movieId=577, title='Andre (1994)', genres='Adventure|Children|Drama'),
#  Row(movieId=579, title='Escort, The (Scorta, La) (1993)', genres='Crime|Thriller'),
#  Row(movieId=580, title='Princess Caraboo (1994)', genres='Drama'),
#  Row(movieId=581, title='Celluloid Closet, The (1995)', genres='Documentary'),
#  Row(movieId=583, title='Dear Diary (Caro Diario) (1994)', genres='Comedy|Drama'),
#  Row(movieId=585, title='Brady Bunch Movie, The (1995)', genres='Comedy'),
#  Row(movieId=586, title='Home Alone (1990)', genres='Children|Comedy'),
#  Row(movieId=587, title='Ghost (1990)', genres='Comedy|Drama|Fantasy|Romance|Thriller'),
#  Row(movieId=588, title='Aladdin (1992)', genres='Adventure|Animation|Children|Comedy|Musical'),
#  Row(movieId=589, title='Terminator 2: Judgment Day (1991)', genres='Action|Sci-Fi'),
#  Row(movieId=590, title='Dances with Wolves (1990)', genres='Adventure|Drama|Western'),
#  Row(movieId=592, title='Batman (1989)', genres='Action|Crime|Thriller'),
#  Row(movieId=593, title='Silence of the Lambs, The (1991)', genres='Crime|Horror|Thriller'),
#  Row(movieId=594, title='Snow White and the Seven Dwarfs (1937)', genres='Animation|Children|Drama|Fantasy|Musical'),
#  Row(movieId=595, title='Beauty and the Beast (1991)', genres='Animation|Children|Fantasy|Musical|Romance|IMAX'),
#  Row(movieId=596, title='Pinocchio (1940)', genres='Animation|Children|Fantasy|Musical'),
#  Row(movieId=597, title='Pretty Woman (1990)', genres='Comedy|Romance'),
#  Row(movieId=599, title='Wild Bunch, The (1969)', genres='Adventure|Western'),
#  Row(movieId=600, title='Love and a .45 (1994)', genres='Action|Comedy|Crime'),
#  Row(movieId=602, title='Great Day in Harlem, A (1994)', genres='Documentary'),
#  Row(movieId=605, title='One Fine Day (1996)', genres='Drama|Romance'),
#  Row(movieId=606, title='Candyman: Farewell to the Flesh (1995)', genres='Fantasy|Horror'),
#  Row(movieId=608, title='Fargo (1996)', genres='Comedy|Crime|Drama|Thriller'),
#  Row(movieId=609, title='Homeward Bound II: Lost in San Francisco (1996)', genres='Adventure|Children'),
#  Row(movieId=610, title='Heavy Metal (1981)', genres='Action|Adventure|Animation|Horror|Sci-Fi'),
#  Row(movieId=611, title='Hellraiser: Bloodline (1996)', genres='Action|Horror|Sci-Fi'),
#  Row(movieId=612, title='Pallbearer, The (1996)', genres='Comedy'),
#  Row(movieId=613, title='Jane Eyre (1996)', genres='Drama|Romance'),
#  Row(movieId=615, title='Bread and Chocolate (Pane e cioccolata) (1973)', genres='Comedy|Drama'),
#  Row(movieId=616, title='Aristocats, The (1970)', genres='Animation|Children'),
#  Row(movieId=617, title='Flower of My Secret, The (La flor de mi secreto) (1995)', genres='Comedy|Drama'),
#  Row(movieId=618, title='Two Much (1995)', genres='Comedy|Romance'),
#  Row(movieId=619, title='Ed (1996)', genres='Comedy'),
#  Row(movieId=626, title='Thin Line Between Love and Hate, A (1996)', genres='Comedy'),
#  Row(movieId=627, title='Last Supper, The (1995)', genres='Drama|Thriller'),
#  Row(movieId=628, title='Primal Fear (1996)', genres='Crime|Drama|Mystery|Thriller'),
#  Row(movieId=631, title='All Dogs Go to Heaven 2 (1996)', genres='Adventure|Animation|Children|Fantasy|Musical|Romance'),
#  Row(movieId=632, title='Land and Freedom (Tierra y libertad) (1995)', genres='Drama|War'),
#  Row(movieId=633, title='Denise Calls Up (1995)', genres='Comedy'),
#  Row(movieId=634, title='Theodore Rex (1995)', genres='Comedy'),
#  Row(movieId=635, title='Family Thing, A (1996)', genres='Comedy|Drama'),
#  Row(movieId=636, title='Frisk (1995)', genres='Drama'),
#  Row(movieId=637, title='Sgt. Bilko (1996)', genres='Comedy'),
#  Row(movieId=638, title='Jack and Sarah (1995)', genres='Romance'),
#  Row(movieId=639, title='Girl 6 (1996)', genres='Comedy|Drama'),
#  Row(movieId=640, title='Diabolique (1996)', genres='Drama|Thriller'),
#  Row(movieId=645, title='Nelly & Monsieur Arnaud (1995)', genres='Drama'),
#  Row(movieId=647, title='Courage Under Fire (1996)', genres='Action|Crime|Drama|War'),
#  Row(movieId=648, title='Mission: Impossible (1996)', genres='Action|Adventure|Mystery|Thriller'),
#  Row(movieId=649, title='Cold Fever (Á köldum klaka) (1995)', genres='Comedy|Drama'),
#  Row(movieId=650, title='Moll Flanders (1996)', genres='Drama'),
#  Row(movieId=653, title='Dragonheart (1996)', genres='Action|Adventure|Fantasy'),
#  Row(movieId=656, title='Eddie (1996)', genres='Comedy'),
#  Row(movieId=661, title='James and the Giant Peach (1996)', genres='Adventure|Animation|Children|Fantasy|Musical'),
#  Row(movieId=662, title='Fear (1996)', genres='Thriller'),
#  Row(movieId=663, title='Kids in the Hall: Brain Candy (1996)', genres='Comedy'),
#  Row(movieId=665, title='Underground (1995)', genres='Comedy|Drama|War'),
#  Row(movieId=667, title='Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996)', genres='Action'),
#  Row(movieId=668, title='Song of the Little Road (Pather Panchali) (1955)', genres='Drama'),
#  Row(movieId=670, title='World of Apu, The (Apur Sansar) (1959)', genres='Drama'),
#  Row(movieId=671, title='Mystery Science Theater 3000: The Movie (1996)', genres='Comedy|Sci-Fi'),
#  Row(movieId=673, title='Space Jam (1996)', genres='Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi'),
#  Row(movieId=674, title='Barbarella (1968)', genres='Adventure|Comedy|Sci-Fi'),
#  Row(movieId=678, title='Some Folks Call It a Sling Blade (1993)', genres='Drama|Thriller'),
#  Row(movieId=679, title='Run of the Country, The (1995)', genres='Drama'),
#  Row(movieId=680, title='Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965)', genres='Drama|Mystery|Romance|Sci-Fi|Thriller'),
#  Row(movieId=685, title="It's My Party (1996)", genres='Drama'),
#  Row(movieId=688, title='Operation Dumbo Drop (1995)', genres='Action|Adventure|Comedy|War'),
#  Row(movieId=691, title='Mrs. Winterbourne (1996)', genres='Comedy|Romance'),
#  Row(movieId=692, title='Solo (1996)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=694, title='Substitute, The (1996)', genres='Action|Crime|Drama'),
#  Row(movieId=695, title='True Crime (1996)', genres='Mystery|Thriller'),
#  Row(movieId=697, title='Feeling Minnesota (1996)', genres='Drama|Romance'),
#  Row(movieId=698, title='Delta of Venus (1995)', genres='Drama'),
#  Row(movieId=700, title='Angus (1995)', genres='Comedy'),
#  Row(movieId=703, title='Boys (1996)', genres='Drama'),
#  Row(movieId=704, title='Quest, The (1996)', genres='Action|Adventure'),
#  Row(movieId=706, title='Sunset Park (1996)', genres='Drama'),
#  Row(movieId=707, title='Mulholland Falls (1996)', genres='Crime|Drama|Thriller'),
#  Row(movieId=708, title='Truth About Cats & Dogs, The (1996)', genres='Comedy|Romance'),
#  Row(movieId=709, title='Oliver & Company (1988)', genres='Adventure|Animation|Children|Comedy|Musical'),
#  Row(movieId=710, title='Celtic Pride (1996)', genres='Comedy'),
#  Row(movieId=711, title='Flipper (1996)', genres='Adventure|Children'),
#  Row(movieId=714, title='Dead Man (1995)', genres='Drama|Mystery|Western'),
#  Row(movieId=715, title='Horseman on the Roof, The (Hussard sur le toit, Le) (1995)', genres='Drama|Romance'),
#  Row(movieId=718, title='Visitors, The (Visiteurs, Les) (1993)', genres='Comedy|Fantasy|Sci-Fi'),
#  Row(movieId=719, title='Multiplicity (1996)', genres='Comedy'),
#  Row(movieId=720, title='Wallace & Gromit: The Best of Aardman Animation (1996)', genres='Adventure|Animation|Comedy'),
#  Row(movieId=722, title='Haunted World of Edward D. Wood Jr., The (1996)', genres='Documentary'),
#  Row(movieId=724, title='Craft, The (1996)', genres='Drama|Fantasy|Horror|Thriller'),
#  Row(movieId=725, title='Great White Hype, The (1996)', genres='Comedy'),
#  Row(movieId=726, title='Last Dance (1996)', genres='Drama'),
#  Row(movieId=728, title='Cold Comfort Farm (1995)', genres='Comedy'),
#  Row(movieId=731, title="Heaven's Prisoners (1996)", genres='Crime|Thriller'),
#  Row(movieId=733, title='Rock, The (1996)', genres='Action|Adventure|Thriller'),
#  Row(movieId=735, title='Cemetery Man (Dellamorte Dellamore) (1994)', genres='Horror'),
#  Row(movieId=736, title='Twister (1996)', genres='Action|Adventure|Romance|Thriller'),
#  Row(movieId=737, title='Barb Wire (1996)', genres='Action|Sci-Fi'),
#  Row(movieId=741, title='Ghost in the Shell (Kôkaku kidôtai) (1995)', genres='Animation|Sci-Fi'),
#  Row(movieId=742, title='Thinner (1996)', genres='Horror|Thriller'),
#  Row(movieId=743, title='Spy Hard (1996)', genres='Comedy'),
#  Row(movieId=745, title='Wallace & Gromit: A Close Shave (1995)', genres='Animation|Children|Comedy'),
#  Row(movieId=747, title='Stupids, The (1996)', genres='Comedy'),
#  Row(movieId=748, title='Arrival, The (1996)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=750, title='Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', genres='Comedy|War'),
#  Row(movieId=757, title='Ashes of Time (Dung che sai duk) (1994)', genres='Drama'),
#  Row(movieId=759, title='Maya Lin: A Strong Clear Vision (1994)', genres='Documentary'),
# ...
#  Row(movieId=1057, title='Everyone Says I Love You (1996)', genres='Comedy|Musical|Romance'),
#  Row(movieId=1059, title="William Shakespeare's Romeo + Juliet (1996)", genres='Drama|Romance'),
#  Row(movieId=1060, title='Swingers (1996)', genres='Comedy|Drama'),
#  Row(movieId=1061, title='Sleepers (1996)', genres='Thriller'),
#  Row(movieId=1064, title='Aladdin and the King of Thieves (1996)', genres='Animation|Children|Comedy|Fantasy|Musical|Romance'),
#  Row(movieId=1066, title='Shall We Dance (1937)', genres='Comedy|Musical|Romance'),
#  Row(movieId=1068, title='Crossfire (1947)', genres='Crime|Film-Noir'),
#  Row(movieId=1073, title='Willy Wonka & the Chocolate Factory (1971)', genres='Children|Comedy|Fantasy|Musical'),
#  Row(movieId=1076, title='Innocents, The (1961)', genres='Drama|Horror|Thriller'),
#  Row(movieId=1077, title='Sleeper (1973)', genres='Comedy|Sci-Fi'),
#  Row(movieId=1078, title='Bananas (1971)', genres='Comedy|War'),
#  Row(movieId=1079, title='Fish Called Wanda, A (1988)', genres='Comedy|Crime'),
#  Row(movieId=1080, title="Monty Python's Life of Brian (1979)", genres='Comedy'),
#  Row(movieId=1081, title='Victor/Victoria (1982)', genres='Comedy|Musical|Romance'),
#  Row(movieId=1082, title='Candidate, The (1972)', genres='Drama'),
#  Row(movieId=1083, title='Great Race, The (1965)', genres='Comedy|Musical'),
#  Row(movieId=1084, title='Bonnie and Clyde (1967)', genres='Crime|Drama'),
#  Row(movieId=1085, title='Old Man and the Sea, The (1958)', genres='Adventure|Drama'),
#  Row(movieId=1086, title='Dial M for Murder (1954)', genres='Crime|Mystery|Thriller'),
#  Row(movieId=1088, title='Dirty Dancing (1987)', genres='Drama|Musical|Romance'),
#  Row(movieId=1089, title='Reservoir Dogs (1992)', genres='Crime|Mystery|Thriller'),
#  Row(movieId=1090, title='Platoon (1986)', genres='Drama|War'),
#  Row(movieId=1091, title="Weekend at Bernie's (1989)", genres='Comedy'),
#  Row(movieId=1092, title='Basic Instinct (1992)', genres='Crime|Mystery|Thriller'),
#  Row(movieId=1093, title='Doors, The (1991)', genres='Drama'),
#  Row(movieId=1094, title='Crying Game, The (1992)', genres='Drama|Romance|Thriller'),
#  Row(movieId=1095, title='Glengarry Glen Ross (1992)', genres='Drama'),
#  Row(movieId=1096, title="Sophie's Choice (1982)", genres='Drama'),
#  Row(movieId=1097, title='E.T. the Extra-Terrestrial (1982)', genres='Children|Drama|Sci-Fi'),
#  Row(movieId=1099, title='Christmas Carol, A (1938)', genres='Children|Drama|Fantasy'),
#  Row(movieId=1100, title='Days of Thunder (1990)', genres='Action|Drama|Romance'),
#  Row(movieId=1101, title='Top Gun (1986)', genres='Action|Romance'),
#  Row(movieId=1103, title='Rebel Without a Cause (1955)', genres='Drama'),
#  Row(movieId=1104, title='Streetcar Named Desire, A (1951)', genres='Drama'),
#  Row(movieId=1105, title='Children of the Corn IV: The Gathering (1996)', genres='Horror'),
#  Row(movieId=1107, title='Loser (1991)', genres='Comedy'),
#  Row(movieId=1111, title="Microcosmos (Microcosmos: Le peuple de l'herbe) (1996)", genres='Documentary'),
#  Row(movieId=1112, title='Palookaville (1996)', genres='Action|Comedy|Drama'),
#  Row(movieId=1114, title='Funeral, The (1996)', genres='Crime|Drama'),
#  Row(movieId=1116, title='Single Girl, A (Fille seule, La) (1995)', genres='Drama'),
#  Row(movieId=1117, title='Eighth Day, The (Huitième jour, Le) (1996)', genres='Drama'),
#  Row(movieId=1119, title='Drunks (1995)', genres='Drama'),
#  Row(movieId=1120, title='People vs. Larry Flynt, The (1996)', genres='Comedy|Drama'),
#  Row(movieId=1121, title='Glory Daze (1995)', genres='Drama'),
#  Row(movieId=1123, title='Perfect Candidate, A (1996)', genres='Documentary'),
#  Row(movieId=1124, title='On Golden Pond (1981)', genres='Drama'),
#  Row(movieId=1125, title='Return of the Pink Panther, The (1975)', genres='Comedy|Crime'),
#  Row(movieId=1126, title='Drop Dead Fred (1991)', genres='Comedy|Fantasy'),
#  Row(movieId=1127, title='Abyss, The (1989)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(movieId=1128, title='Fog, The (1980)', genres='Horror'),
#  Row(movieId=1129, title='Escape from New York (1981)', genres='Action|Adventure|Sci-Fi|Thriller'),
#  Row(movieId=1130, title='Howling, The (1980)', genres='Horror|Mystery'),
#  Row(movieId=1131, title='Jean de Florette (1986)', genres='Drama|Mystery'),
#  Row(movieId=1132, title='Manon of the Spring (Manon des sources) (1986)', genres='Drama'),
#  Row(movieId=1135, title='Private Benjamin (1980)', genres='Comedy'),
#  Row(movieId=1136, title='Monty Python and the Holy Grail (1975)', genres='Adventure|Comedy|Fantasy'),
#  Row(movieId=1137, title='Hustler White (1996)', genres='Romance'),
#  Row(movieId=1140, title='Entertaining Angels: The Dorothy Day Story (1996)', genres='Drama'),
#  Row(movieId=1144, title='Line King: The Al Hirschfeld Story, The (1996)', genres='Documentary'),
#  Row(movieId=1147, title='When We Were Kings (1996)', genres='Documentary'),
#  Row(movieId=1148, title='Wallace & Gromit: The Wrong Trousers (1993)', genres='Animation|Children|Comedy|Crime'),
#  Row(movieId=1150, title='Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)', genres='Drama'),
#  Row(movieId=1151, title='Lesson Faust (1994)', genres='Animation|Comedy|Drama|Fantasy'),
#  Row(movieId=1156, title='Children Are Watching Us, The (Bambini ci guardano, I) (1944)', genres='Drama'),
#  Row(movieId=1161, title='Tin Drum, The (Blechtrommel, Die) (1979)', genres='Drama|War'),
#  Row(movieId=1162, title='Ruling Class, The (1972)', genres='Comedy|Drama'),
#  Row(movieId=1163, title='Mina Tannenbaum (1994)', genres='Drama'),
#  Row(movieId=1167, title='Dear God (1996)', genres='Comedy'),
#  Row(movieId=1170, title='Best of the Best 3: No Turning Back (1995)', genres='Action'),
#  Row(movieId=1171, title='Bob Roberts (1992)', genres='Comedy'),
#  Row(movieId=1172, title='Cinema Paradiso (Nuovo cinema Paradiso) (1989)', genres='Drama'),
#  Row(movieId=1173, title='Cook the Thief His Wife & Her Lover, The (1989)', genres='Comedy|Drama'),
#  Row(movieId=1175, title='Delicatessen (1991)', genres='Comedy|Drama|Romance'),
#  Row(movieId=1176, title='Double Life of Veronique, The (Double Vie de Véronique, La) (1991)', genres='Drama|Fantasy|Romance'),
#  Row(movieId=1177, title='Enchanted April (1992)', genres='Drama|Romance'),
#  Row(movieId=1178, title='Paths of Glory (1957)', genres='Drama|War'),
#  Row(movieId=1179, title='Grifters, The (1990)', genres='Crime|Drama|Film-Noir'),
#  Row(movieId=1180, title='Hear My Song (1991)', genres='Comedy'),
#  Row(movieId=1183, title='English Patient, The (1996)', genres='Drama|Romance|War'),
#  Row(movieId=1184, title='Mediterraneo (1991)', genres='Comedy|Drama'),
#  Row(movieId=1185, title='My Left Foot (1989)', genres='Drama'),
#  Row(movieId=1186, title='Sex, Lies, and Videotape (1989)', genres='Drama'),
#  Row(movieId=1187, title='Passion Fish (1992)', genres='Drama'),
#  Row(movieId=1188, title='Strictly Ballroom (1992)', genres='Comedy|Romance'),
#  Row(movieId=1189, title='Thin Blue Line, The (1988)', genres='Documentary'),
#  Row(movieId=1190, title='Tie Me Up! Tie Me Down! (¡Átame!) (1990)', genres='Crime|Drama|Romance'),
#  Row(movieId=1191, title='Madonna: Truth or Dare (1991)', genres='Documentary|Musical'),
#  Row(movieId=1192, title='Paris Is Burning (1990)', genres='Documentary'),
#  Row(movieId=1193, title="One Flew Over the Cuckoo's Nest (1975)", genres='Drama'),
#  Row(movieId=1194, title="Cheech and Chong's Up in Smoke (1978)", genres='Comedy'),
#  Row(movieId=1196, title='Star Wars: Episode V - The Empire Strikes Back (1980)', genres='Action|Adventure|Sci-Fi'),
#  Row(movieId=1197, title='Princess Bride, The (1987)', genres='Action|Adventure|Comedy|Fantasy|Romance'),
#  Row(movieId=1198, title='Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', genres='Action|Adventure'),
#  Row(movieId=1199, title='Brazil (1985)', genres='Fantasy|Sci-Fi'),
#  Row(movieId=1200, title='Aliens (1986)', genres='Action|Adventure|Horror|Sci-Fi'),
#  Row(movieId=1201, title='Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', genres='Action|Adventure|Western'),
#  Row(movieId=1202, title='Withnail & I (1987)', genres='Comedy'),
#  Row(movieId=1203, title='12 Angry Men (1957)', genres='Drama'),
#  Row(movieId=1204, title='Lawrence of Arabia (1962)', genres='Adventure|Drama|War'),
#  Row(movieId=1206, title='Clockwork Orange, A (1971)', genres='Crime|Drama|Sci-Fi|Thriller'),
#  Row(movieId=1207, title='To Kill a Mockingbird (1962)', genres='Drama'),
#  Row(movieId=1208, title='Apocalypse Now (1979)', genres='Action|Drama|War'),
#  Row(movieId=1209, title="Once Upon a Time in the West (C'era una volta il West) (1968)", genres='Action|Drama|Western'),
#  Row(movieId=1210, title='Star Wars: Episode VI - Return of the Jedi (1983)', genres='Action|Adventure|Sci-Fi'),
#  Row(movieId=1211, title='Wings of Desire (Himmel über Berlin, Der) (1987)', genres='Drama|Fantasy|Romance'),
#  Row(movieId=1212, title='Third Man, The (1949)', genres='Film-Noir|Mystery|Thriller'),
#  Row(movieId=1213, title='Goodfellas (1990)', genres='Crime|Drama'),
#  Row(movieId=1214, title='Alien (1979)', genres='Horror|Sci-Fi'),
#  Row(movieId=1215, title='Army of Darkness (1993)', genres='Action|Adventure|Comedy|Fantasy|Horror'),
#  Row(movieId=1216, title='Big Blue, The (Grand bleu, Le) (1988)', genres='Adventure|Drama|Romance'),
#  Row(movieId=1217, title='Ran (1985)', genres='Drama|War'),
#  Row(movieId=1218, title='Killer, The (Die xue shuang xiong) (1989)', genres='Action|Crime|Drama|Thriller'),
#  Row(movieId=1219, title='Psycho (1960)', genres='Crime|Horror'),
#  Row(movieId=1220, title='Blues Brothers, The (1980)', genres='Action|Comedy|Musical'),
#  Row(movieId=1221, title='Godfather: Part II, The (1974)', genres='Crime|Drama'),
#  Row(movieId=1222, title='Full Metal Jacket (1987)', genres='Drama|War'),
#  Row(movieId=1223, title='Grand Day Out with Wallace and Gromit, A (1989)', genres='Adventure|Animation|Children|Comedy|Sci-Fi'),
#  Row(movieId=1224, title='Henry V (1989)', genres='Action|Drama|Romance|War'),
#  Row(movieId=1225, title='Amadeus (1984)', genres='Drama'),
#  Row(movieId=1226, title='Quiet Man, The (1952)', genres='Drama|Romance'),
#  Row(movieId=1227, title='Once Upon a Time in America (1984)', genres='Crime|Drama'),
#  Row(movieId=1228, title='Raging Bull (1980)', genres='Drama'),
#  Row(movieId=1230, title='Annie Hall (1977)', genres='Comedy|Romance'),
#  Row(movieId=1231, title='Right Stuff, The (1983)', genres='Drama'),
#  Row(movieId=1232, title='Stalker (1979)', genres='Drama|Mystery|Sci-Fi'),
#  Row(movieId=1233, title='Boot, Das (Boat, The) (1981)', genres='Action|Drama|War'),
#  Row(movieId=1234, title='Sting, The (1973)', genres='Comedy|Crime'),
#  Row(movieId=1235, title='Harold and Maude (1971)', genres='Comedy|Drama|Romance'),
#  Row(movieId=1236, title='Trust (1990)', genres='Comedy|Drama|Romance'),
#  Row(movieId=1237, title='Seventh Seal, The (Sjunde inseglet, Det) (1957)', genres='Drama'),
#  Row(movieId=1238, title='Local Hero (1983)', genres='Comedy'),
#  Row(movieId=1240, title='Terminator, The (1984)', genres='Action|Sci-Fi|Thriller'),
#  Row(movieId=1241, title='Dead Alive (Braindead) (1992)', genres='Comedy|Fantasy|Horror'),
#  Row(movieId=1242, title='Glory (1989)', genres='Drama|War'),
#  Row(movieId=1243, title='Rosencrantz and Guildenstern Are Dead (1990)', genres='Comedy|Drama'),
#  Row(movieId=1244, title='Manhattan (1979)', genres='Comedy|Drama|Romance'),
#  Row(movieId=1245, title="Miller's Crossing (1990)", genres='Crime|Drama|Film-Noir|Thriller'),
#  Row(movieId=1246, title='Dead Poets Society (1989)', genres='Drama'),
#  Row(movieId=1247, title='Graduate, The (1967)', genres='Comedy|Drama|Romance'),
#  Row(movieId=1248, title='Touch of Evil (1958)', genres='Crime|Film-Noir|Thriller'),
#  Row(movieId=1249, title='Femme Nikita, La (Nikita) (1990)', genres='Action|Crime|Romance|Thriller'),
#  Row(movieId=1250, title='Bridge on the River Kwai, The (1957)', genres='Adventure|Drama|War'),
#  Row(movieId=1251, title='8 1/2 (8½) (1963)', genres='Drama|Fantasy'),
#  Row(movieId=1252, title='Chinatown (1974)', genres='Crime|Film-Noir|Mystery|Thriller'),
#  Row(movieId=1253, title='Day the Earth Stood Still, The (1951)', genres='Drama|Sci-Fi|Thriller'),
#  Row(movieId=1254, title='Treasure of the Sierra Madre, The (1948)', genres='Action|Adventure|Drama|Western'),
#  Row(movieId=1255, title='Bad Taste (1987)', genres='Comedy|Horror|Sci-Fi'),
#  Row(movieId=1256, title='Duck Soup (1933)', genres='Comedy|Musical|War'),
#  Row(movieId=1257, title='Better Off Dead... (1985)', genres='Comedy|Romance'),
#  Row(movieId=1258, title='Shining, The (1980)', genres='Horror'),
#  Row(movieId=1259, title='Stand by Me (1986)', genres='Adventure|Drama'),
#  Row(movieId=1260, title='M (1931)', genres='Crime|Film-Noir|Thriller'),
#  Row(movieId=1261, title='Evil Dead II (Dead by Dawn) (1987)', genres='Action|Comedy|Fantasy|Horror'),
#  Row(movieId=1262, title='Great Escape, The (1963)', genres='Action|Adventure|Drama|War'),
#  Row(movieId=1263, title='Deer Hunter, The (1978)', genres='Drama|War'),
#  Row(movieId=1264, title='Diva (1981)', genres='Action|Drama|Mystery|Romance|Thriller'),
#  Row(movieId=1265, title='Groundhog Day (1993)', genres='Comedy|Fantasy|Romance'),
#  Row(movieId=1266, title='Unforgiven (1992)', genres='Drama|Western'),
#  Row(movieId=1267, title='Manchurian Candidate, The (1962)', genres='Crime|Thriller|War'),
#  Row(movieId=1268, title='Pump Up the Volume (1990)', genres='Comedy|Drama'),
#  Row(movieId=1269, title='Arsenic and Old Lace (1944)', genres='Comedy|Mystery|Thriller'),
#  Row(movieId=1270, title='Back to the Future (1985)', genres='Adventure|Comedy|Sci-Fi'),
#  Row(movieId=1271, title='Fried Green Tomatoes (1991)', genres='Comedy|Crime|Drama'),
#  Row(movieId=1272, title='Patton (1970)', genres='Drama|War'),
#  Row(movieId=1273, title='Down by Law (1986)', genres='Comedy|Drama|Film-Noir'),
#  Row(movieId=1274, title='Akira (1988)', genres='Action|Adventure|Animation|Sci-Fi'),
#  Row(movieId=1275, title='Highlander (1986)', genres='Action|Adventure|Fantasy'),
#  Row(movieId=1276, title='Cool Hand Luke (1967)', genres='Drama'),
#  Row(movieId=1277, title='Cyrano de Bergerac (1990)', genres='Comedy|Drama|Romance'),
#  Row(movieId=1278, title='Young Frankenstein (1974)', genres='Comedy|Fantasy'),
#  Row(movieId=1279, title='Night on Earth (1991)', genres='Comedy|Drama'),
#  Row(movieId=1280, title='Raise the Red Lantern (Da hong deng long gao gao gua) (1991)', genres='Drama'),
#  Row(movieId=1281, title='Great Dictator, The (1940)', genres='Comedy|Drama|War'),
#  Row(movieId=1282, title='Fantasia (1940)', genres='Animation|Children|Fantasy|Musical'),
#  Row(movieId=1283, title='High Noon (1952)', genres='Drama|Western'),
#  Row(movieId=1284, title='Big Sleep, The (1946)', genres='Crime|Film-Noir|Mystery'),
#  Row(movieId=1285, title='Heathers (1989)', genres='Comedy'),
#  Row(movieId=1286, title='Somewhere in Time (1980)', genres='Drama|Romance'),
#  Row(movieId=1287, title='Ben-Hur (1959)', genres='Action|Adventure|Drama'),
#  Row(movieId=1288, title='This Is Spinal Tap (1984)', genres='Comedy'),
#  Row(movieId=1289, title='Koyaanisqatsi (a.k.a. Koyaanisqatsi: Life Out of Balance) (1983)', genres='Documentary'),
#  Row(movieId=1290, title='Some Kind of Wonderful (1987)', genres='Drama|Romance'),
#  Row(movieId=1291, title='Indiana Jones and the Last Crusade (1989)', genres='Action|Adventure'),
#  Row(movieId=1292, title='Being There (1979)', genres='Comedy|Drama'),
#  Row(movieId=1293, title='Gandhi (1982)', genres='Drama'),
#  Row(movieId=1295, title='Unbearable Lightness of Being, The (1988)', genres='Drama'),
#  Row(movieId=1296, title='Room with a View, A (1986)', genres='Drama|Romance'),
#  Row(movieId=1297, title='Real Genius (1985)', genres='Comedy'),
#  Row(movieId=1298, title='Pink Floyd: The Wall (1982)', genres='Drama|Musical'),
#  Row(movieId=1299, title='Killing Fields, The (1984)', genres='Drama|War'),
#  Row(movieId=1300, title='My Life as a Dog (Mitt liv som hund) (1985)', genres='Comedy|Drama'),
#  Row(movieId=1301, title='Forbidden Planet (1956)', genres='Drama|Sci-Fi'),
#  ...]

# %%
movieDf.take(2)
# Out:
# [Row(movieId=1, title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy'),
#  Row(movieId=2, title='Jumanji (1995)', genres='Adventure|Children|Fantasy')]

# %%
ratingDf.show(1)
# add new columns/drive new columns from existing data
df3 = ratingDf.withColumn("rating_adjusted", ratingDf.rating + .2  )
df3.show(1)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# +------+-------+------+---------+
# only showing top 1 row
#
# +------+-------+------+---------+---------------+
# |userId|movieId|rating|timestamp|rating_adjusted|
# +------+-------+------+---------+---------------+
# |     1|      1|   4.0|964982703|            4.2|
# +------+-------+------+---------+---------------+
# only showing top 1 row

# %%
ratingDf.show(1)
# rename the column in the df
# existing col, new column
df2 = ratingDf.withColumnRenamed("rating", "ratings")
df2.show(1)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# +------+-------+------+---------+
# only showing top 1 row
#
# +------+-------+-------+---------+
# |userId|movieId|ratings|timestamp|
# +------+-------+-------+---------+
# |     1|      1|    4.0|964982703|
# +------+-------+-------+---------+
# only showing top 1 row

# %%
# select variance
# select all columns
df2 = ratingDf.select("*")
df2.show(1)
df2 = ratingDf.select("movieId", "rating")
df2.show(1)
# use .alias to give a name
df2 = ratingDf.select(ratingDf.userId, 
                     (ratingDf.rating + 0.2).alias("rating_adjusted") )
df2.show(1)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# +------+-------+------+---------+
# only showing top 1 row
#
# +-------+------+
# |movieId|rating|
# +-------+------+
# |      1|   4.0|
# +-------+------+
# only showing top 1 row
#
# +------+---------------+
# |userId|rating_adjusted|
# +------+---------------+
# |     1|            4.2|
# +------+---------------+
# only showing top 1 row

# %%
# filter, apply predicates/conditions
# filter, where functions. where is an alias of filter, both are same
df2 = ratingDf.filter(ratingDf.rating > 4)
df2.show(3)

df2 = ratingDf.where(ratingDf.rating > 4)
df2.show(3)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# |     1|    101|   5.0|964980868|
# +------+-------+------+---------+
# only showing top 3 rows
#
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# |     1|    101|   5.0|964980868|
# +------+-------+------+---------+
# only showing top 3 rows

# %%
# multiple conditions
df2 = ratingDf.filter( (ratingDf.rating >=3) & (ratingDf.rating <=4))
df2.show(4)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     70|   3.0|964982400|
# +------+-------+------+---------+
# only showing top 4 rows

# %%
from pyspark.sql.functions import col

df2 = ratingDf.filter( (col("rating") >=3) & (col("rating") <=4))
df2.show(4)
# Out:
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     70|   3.0|964982400|
# +------+-------+------+---------+
# only showing top 4 rows

# %%
from pyspark.sql.functions import col, asc, desc
# sort data by ascending order/ default
df2 = ratingDf.sort("rating")
df2.show(5)
# sort data by ascending by explitly
df2 = ratingDf.sort(asc("rating"))
df2.show(5)
# sort data by descending order
df2 = ratingDf.sort(desc("rating"))
df2.show(5)
# Out:
# +------+-------+------+----------+
# |userId|movieId|rating| timestamp|
# +------+-------+------+----------+
# |     3|     31|   0.5|1306463578|
# |     3|    914|   0.5|1306463567|
# |     3|    527|   0.5|1306464275|
# |     3|    688|   0.5|1306464228|
# |     3|    720|   0.5|1306463595|
# +------+-------+------+----------+
# only showing top 5 rows
#
# +------+-------+------+----------+
# |userId|movieId|rating| timestamp|
# +------+-------+------+----------+
# |     3|     31|   0.5|1306463578|
# |     3|    914|   0.5|1306463567|
# |     3|    527|   0.5|1306464275|
# |     3|    688|   0.5|1306464228|
# |     3|    720|   0.5|1306463595|
# +------+-------+------+----------+
# only showing top 5 rows
#
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|    101|   5.0|964980868|
# |     1|    216|   5.0|964981208|
# |     1|    151|   5.0|964984041|
# |     1|    157|   5.0|964984100|
# |     1|     47|   5.0|964983815|
# +------+-------+------+---------+
# only showing top 5 rows

# %%
# aggregation count
from pyspark.sql.functions import col, desc, avg, count
# count, groupBy
# a movie, rated by more users, dones't count avg rating
# filter, ensure that total_ratings >= 100 users
mostPopularDf = ratingDf\
                .groupBy("movieId")\
                .agg(count("userId"))\
                .withColumnRenamed("count(userId)", "total_ratings")\
                .filter(col("total_ratings") >= 100)\                
                .sort(desc("total_ratings"))\
                

mostPopularDf.show(200)
# Out:
# +-------+-------------+
# |movieId|total_ratings|
# +-------+-------------+
# |    356|          329|
# |    318|          317|
# |    296|          307|
# |    593|          279|
# |   2571|          278|
# |    260|          251|
# |    480|          238|
# |    110|          237|
# |    589|          224|
# |    527|          220|
# |   2959|          218|
# |      1|          215|
# |   1196|          211|
# |     50|          204|
# |   2858|          204|
# |     47|          203|
# |    780|          202|
# |    150|          201|
# |   1198|          200|
# |   4993|          198|
# |   1210|          196|
# |    858|          192|
# |    457|          190|
# |    592|          189|
# |   5952|          188|
# |   2028|          188|
# |   7153|          185|
# |    588|          183|
# |    608|          181|
# |   2762|          179|
# |    380|          178|
# |     32|          177|
# |    364|          172|
# |    377|          171|
# |   1270|          171|
# |   4306|          170|
# |   3578|          170|
# |   1580|          165|
# |    590|          164|
# |    648|          162|
# |    344|          161|
# |   4226|          159|
# |    367|          157|
# |   6539|          149|
# |  58559|          149|
# |   1214|          146|
# |    595|          146|
# |   1036|          145|
# |    500|          144|
# |    165|          144|
# |  79132|          143|
# |   1265|          143|
# |   1197|          142|
# |   1704|          141|
# |   6377|          141|
# |   2628|          140|
# |   1721|          140|
# |   1291|          140|
# |    316|          140|
# |    153|          137|
# |   1136|          136|
# |    597|          135|
# |   3793|          133|
# |   1193|          133|
# |    231|          133|
# |    293|          133|
# |     10|          132|
# |   4886|          132|
# |   7361|          131|
# |   6874|          131|
# |   1089|          131|
# |   1240|          131|
# |   1221|          129|
# |   2329|          129|
# |     34|          128|
# |   1200|          126|
# |   1213|          126|
# |   8961|          125|
# |   1682|          125|
# |    541|          124|
# |    736|          123|
# |   4995|          123|
# |   5349|          122|
# |   1097|          122|
# |    733|          121|
# |   2683|          121|
# |   5445|          120|
# |   4973|          120|
# |   1206|          120|
# |   2716|          120|
# |   4963|          119|
# |   1073|          119|
# |  33794|          116|
# |   1527|          116|
# |    586|          116|
# |   5989|          115|
# |    587|          115|
# |    208|          115|
# |   1968|          113|
# |   5418|          112|
# |    185|          112|
# |   3147|          111|
# |    349|          110|
# |      2|          110|
# |   7438|          110|
# |   3996|          110|
# |    924|          109|
# |   1258|          109|
# |   2918|          109|
# |   4878|          109|
# |    253|          109|
# |    329|          108|
# |   2115|          108|
# |   4896|          107|
# |   1208|          107|
# |  48516|          107|
# |   1732|          106|
# |    539|          106|
# |   1923|          105|
# |  68954|          105|
# |     39|          104|
# |    111|          104|
# |    223|          104|
# |  60069|          104|
# |    161|          103|
# |    357|          103|
# |   2706|          103|
# |      6|          102|
# |   5816|          102|
# |   1222|          102|
# |    778|          102|
# |    434|          101|
# |    292|          101|
# |    454|          101|
# |    912|          100|
# |   4022|          100|
# |   1517|          100|
# |  44191|          100|
# +-------+-------------+

# %%
movieDf.show(2)
# Out:
# +-------+----------------+--------------------+
# |movieId|           title|              genres|
# +-------+----------------+--------------------+
# |      1|Toy Story (1995)|Adventure|Animati...|
# |      2|  Jumanji (1995)|Adventure|Childre...|
# +-------+----------------+--------------------+
# only showing top 2 rows

# %%
# join mostPopularmovie with movieDf, to get the title of the movie
mostPopularMoviesDf = mostPopularDf\
                      .join(movieDf, 
                            movieDf.movieId == mostPopularDf.movieId)\
                      .select(mostPopularDf.movieId, "title", "total_ratings")



mostPopularMoviesDf.show(5)
# Out:
# +-------+--------------------+-------------+
# |movieId|               title|total_ratings|
# +-------+--------------------+-------------+
# |    356| Forrest Gump (1994)|          329|
# |    318|Shawshank Redempt...|          317|
# |    296| Pulp Fiction (1994)|          307|
# |    593|Silence of the La...|          279|
# |   2571|  Matrix, The (1999)|          278|
# +-------+--------------------+-------------+
# only showing top 5 rows

# %%
# perform two aggregates, count, avg, 

# aggregation of count of number of votes, +
# aggregation of avg voting
from pyspark.sql.functions import col, desc, avg, count
# count, groupBy
# a movie, rated by more users, dones't count avg rating
# filter, ensure that total_ratings >= 100 users
mostPopularDf = ratingDf\
                .groupBy("movieId")\
                .agg(count("userId").alias("total_ratings"), 
                     avg("rating").alias("avg_rating") )\
                .filter( (col("total_ratings") >= 100) &
                         (col("avg_rating") >= 3))\
                .sort(desc("total_ratings"))
                
mostPopularDf.show(200)
# Out:
# +-------+-------------+------------------+
# |movieId|total_ratings|        avg_rating|
# +-------+-------------+------------------+
# |    356|          329| 4.164133738601824|
# |    318|          317| 4.429022082018927|
# |    296|          307| 4.197068403908795|
# |    593|          279| 4.161290322580645|
# |   2571|          278| 4.192446043165468|
# |    260|          251| 4.231075697211155|
# |    480|          238|              3.75|
# |    110|          237| 4.031645569620253|
# |    589|          224| 3.970982142857143|
# |    527|          220|             4.225|
# |   2959|          218| 4.272935779816514|
# |      1|          215|3.9209302325581397|
# |   1196|          211|4.2156398104265405|
# |     50|          204| 4.237745098039215|
# |   2858|          204| 4.056372549019608|
# |     47|          203|3.9753694581280787|
# |    780|          202|3.4455445544554455|
# |    150|          201| 3.845771144278607|
# |   1198|          200|            4.2075|
# |   4993|          198| 4.106060606060606|
# |   1210|          196| 4.137755102040816|
# |    858|          192|         4.2890625|
# |    457|          190|3.9921052631578946|
# |    592|          189|3.4285714285714284|
# |   5952|          188|4.0212765957446805|
# |   2028|          188|4.1462765957446805|
# |   7153|          185| 4.118918918918919|
# |    588|          183|3.7923497267759565|
# |    608|          181| 4.116022099447513|
# |   2762|          179| 3.893854748603352|
# |    380|          178| 3.497191011235955|
# |     32|          177| 3.983050847457627|
# |    364|          172| 3.941860465116279|
# |    377|          171|3.5292397660818713|
# |   1270|          171| 4.038011695906433|
# |   4306|          170|3.8676470588235294|
# |   3578|          170|3.9382352941176473|
# |   1580|          165| 3.487878787878788|
# |    590|          164|3.8353658536585367|
# |    648|          162| 3.537037037037037|
# |    344|          161| 3.040372670807453|
# |   4226|          159| 4.122641509433962|
# |    367|          157|3.1847133757961785|
# |   6539|          149| 3.778523489932886|
# |  58559|          149| 4.238255033557047|
# |   1214|          146| 3.969178082191781|
# |    595|          146|3.7705479452054793|
# |   1036|          145|3.8620689655172415|
# |    500|          144| 3.388888888888889|
# |    165|          144|3.5555555555555554|
# |  79132|          143| 4.066433566433567|
# |   1265|          143| 3.944055944055944|
# |   1197|          142| 4.232394366197183|
# |   1704|          141| 4.078014184397163|
# |   6377|          141|3.9609929078014185|
# |   1721|          140| 3.414285714285714|
# |   1291|          140| 4.046428571428572|
# |   2628|          140| 3.107142857142857|
# |    316|          140|             3.375|
# |   1136|          136| 4.161764705882353|
# |    597|          135|3.4851851851851854|
# |    293|          133| 4.018796992481203|
# |   3793|          133| 3.699248120300752|
# |    231|          133|3.0601503759398496|
# |   1193|          133| 4.203007518796992|
# |     10|          132| 3.496212121212121|
# |   4886|          132| 3.871212121212121|
# |   1240|          131|3.8969465648854964|
# |   6874|          131|3.9618320610687023|
# |   7361|          131|4.1603053435114505|
# |   1089|          131| 4.202290076335878|
# |   1221|          129|  4.25968992248062|
# |   2329|          129| 4.217054263565892|
# |     34|          128|        3.65234375|
# |   1213|          126|              4.25|
# |   1200|          126|3.9642857142857144|
# |   8961|          125|             3.836|
# |   1682|          125|             3.812|
# |    541|          124| 4.100806451612903|
# |   4995|          123|               4.0|
# |    736|          123| 3.321138211382114|
# |   5349|          122| 3.540983606557377|
# |   1097|          122|3.7663934426229506|
# |    733|          121|3.6404958677685952|
# |   2683|          121|3.1983471074380163|
# |   2716|          120|             3.775|
# |   4973|          120| 4.183333333333334|
# |   5445|          120|            3.6375|
# |   1206|          120| 3.995833333333333|
# |   4963|          119|3.8445378151260505|
# |   1073|          119|3.8739495798319328|
# |   1527|          116|3.7456896551724137|
# |  33794|          116|3.8620689655172415|
# |    587|          115|3.4347826086956523|
# |   5989|          115|3.9217391304347826|
# |   1968|          113|3.7787610619469025|
# |    185|          112|3.0401785714285716|
# |   5418|          112|3.8169642857142856|
# |   3147|          111| 4.148648648648648|
# |   7438|          110| 3.868181818181818|
# |    349|          110|3.6045454545454545|
# |   3996|          110|3.8363636363636364|
# |      2|          110|3.4318181818181817|
# |   2918|          109|3.8394495412844036|
# |    924|          109|3.8944954128440368|
# |    253|          109| 3.458715596330275|
# |   4878|          109| 3.981651376146789|
# |   1258|          109|  4.08256880733945|
# |    329|          108|3.3935185185185186|
# |   2115|          108| 3.638888888888889|
# |   4896|          107|3.7616822429906542|
# |   1208|          107| 4.219626168224299|
# |  48516|          107| 4.252336448598131|
# |    539|          106|3.4716981132075473|
# |   1732|          106|3.9245283018867925|
# |   1923|          105| 3.676190476190476|
# |  68954|          105| 4.004761904761905|
# |     39|          104| 3.293269230769231|
# |    111|          104| 4.105769230769231|
# |    223|          104| 3.855769230769231|
# |  60069|          104|4.0576923076923075|
# |    161|          103|3.6359223300970873|
# |    357|          103|3.5194174757281553|
# |   2706|          103| 3.378640776699029|
# |      6|          102| 3.946078431372549|
# |   1222|          102| 4.098039215686274|
# |   5816|          102|3.5980392156862746|
# |    778|          102|  4.03921568627451|
# |    434|          101|3.0346534653465347|
# |    292|          101|3.4257425742574257|
# |    454|          101|3.5346534653465347|
# |    912|          100|              4.24|
# |   4022|          100|               3.7|
# |   1517|          100|             3.535|
# |  44191|          100|             3.885|
# +-------+-------------+------------------+

# %%
# join mostPopularmovie with movieDf, to get the title of the movie
mostPopularMoviesDf = mostPopularDf\
                      .join(movieDf, 
                            movieDf.movieId == mostPopularDf.movieId)\
                      .select(mostPopularDf.movieId, "title", "total_ratings", "avg_rating")



mostPopularMoviesDf.show(5)
# Out:
# +-------+--------------------+-------------+-----------------+
# |movieId|               title|total_ratings|       avg_rating|
# +-------+--------------------+-------------+-----------------+
# |    356| Forrest Gump (1994)|          329|4.164133738601824|
# |    318|Shawshank Redempt...|          317|4.429022082018927|
# |    296| Pulp Fiction (1994)|          307|4.197068403908795|
# |    593|Silence of the La...|          279|4.161290322580645|
# |   2571|  Matrix, The (1999)|          278|4.192446043165468|
# +-------+--------------------+-------------+-----------------+
# only showing top 5 rows

# %%
# we will write the result to file system local
# create a folder named "output" in c:
# open command prompt
# run below command to assign permission 
#   winutils.exe chmod -R 777 c:\output

#mostPopularMoviesDf.write.mode('overwrite')\
#                         .csv("file:///c:/output/movies.csv")

mostPopularMoviesDf.toPandas()\
                    .to_csv("c:/movies.csv")
