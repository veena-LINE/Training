# %%
import findspark
findspark.init()

# %%
from pyspark import SparkContext, rdd
sc = SparkContext("local[1]", "US-ZIPCODES")

# local[1] will create one partition
# local[*] will use as many cores as possible

# %%
# All other imports
import re

# %% [markdown]
# ----

# %%
rdd_us_zipcodes = sc.textFile("hdfs://192.168.93.128:9000/input/all_us_zipcodes.csv")

# %%
# How many partitions currently?
print(f"Partitions : {rdd_us_zipcodes.getNumPartitions()}")
# Out:
# Partitions : 1

# %%
rdd_header = rdd_us_zipcodes.first()
rdd_zipcodes = rdd_us_zipcodes.filter(lambda l: l != rdd_header).map(lambda l: tuple(l.split(",")))

# %%
rdd_zipcodes.take(4)
# Out:
# [('00501', 'Holtsville', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078'),
#  ('00544', 'Holtsville', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078'),
#  ('01001', 'Agawam', 'MA', 'HAMPDEN', '', '42.140549', '-72.788661'),
#  ('01002', 'Amherst', 'MA', 'HAMPSHIRE', '', '42.367092', '-72.464571')]

# %%
# A way to scale up/down partitioning/chunking data

rdd_us_zipcodes = rdd_zipcodes.repartition(4)
print(f"Partitions : {rdd_us_zipcodes.getNumPartitions()}")
# Out:
# Partitions : 4

# %% [markdown]
# ----

# %%
def show_data(partition_name):
    """Print partition data"""
    print("----------------------------------------------")
    return(element for i, element in enumerate(partition_name) if i <= 5)

rdd = rdd_us_zipcodes.mapPartitions(show_data)
rdd.collect()
# Out:
# [('01010', 'Brimfield', 'MA', 'HAMPDEN', '', '42.108585', '-72.20448'),
#  ('01011', 'Chester', 'MA', 'HAMPDEN', '', '42.294259', '-72.952776'),
#  ('01012', 'Chesterfield', 'MA', 'HAMPSHIRE', '', '42.392274', '-72.825607'),
#  ('01013', 'Chicopee', 'MA', 'HAMPDEN', '', '42.161492', '-72.667341'),
#  ('01014', 'Chicopee', 'MA', 'HAMPDEN', '', '42.170731', '-72.604842'),
#  ('01020', 'Chicopee', 'MA', 'HAMPDEN', '', '42.177492', '-72.562563'),
#  ('01028', 'East Longmeadow', 'MA', 'HAMPDEN', '', '42.062009', '-72.49874'),
#  ('01029', 'East Otis', 'MA', 'BERKSHIRE', '', '42.190904', '-73.051661'),
#  ('01030', 'Feeding Hills', 'MA', 'HAMPDEN', '', '42.189335', '-72.79774'),
#  ('01031', 'Gilbertville', 'MA', 'WORCESTER', '', '42.352554', '-72.205724'),
#  ('01032', 'Goshen', 'MA', 'HAMPSHIRE', '', '42.443837', '-72.819446'),
#  ('01033', 'Granby', 'MA', 'HAMPSHIRE', '', '42.262285', '-72.504086'),
#  ('01038', 'Hatfield', 'MA', 'HAMPSHIRE', '', '42.387269', '-72.643081'),
#  ('01039', 'Haydenville', 'MA', 'HAMPSHIRE', '', '42.35641', '-72.682127'),
#  ('01040', 'Holyoke', 'MA', 'HAMPDEN', '', '42.198291', '-72.64207'),
#  ('01041', 'Holyoke', 'MA', 'HAMPDEN', '', '42.170731', '-72.604842'),
#  ('01050', 'Huntington', 'MA', 'HAMPSHIRE', '', '42.313427', '-72.903677'),
#  ('01053', 'Leeds', 'MA', 'HAMPSHIRE', '', '42.353838', '-72.704385'),
#  ('00501', 'Holtsville', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078'),
#  ('00544', 'Holtsville', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078'),
#  ('01001', 'Agawam', 'MA', 'HAMPDEN', '', '42.140549', '-72.788661'),
#  ('01002', 'Amherst', 'MA', 'HAMPSHIRE', '', '42.367092', '-72.464571'),
#  ('01003', 'Amherst', 'MA', 'HAMPSHIRE', '', '42.369562', '-72.63599'),
#  ('01004', 'Amherst', 'MA', 'HAMPSHIRE', '', '42.384494', '-72.513183')]

# %%
rdd.glom().count()  # .glom(): collect data from partitions
# Out:
# 4

# %% [markdown]
# ----

# %%
rdd_zipcodes_keyed = rdd_zipcodes.map(lambda x: (x[0], tuple(x)))

# %%
rdd_zipcodes_keyed.take(2)
# Out:
# [('00501',
#   ('00501', 'Holtsville', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#  ('00544',
#   ('00544', 'Holtsville', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078'))]

# %%
"""
7 is the modulo by which data partitions are grouped (if this is the only argument that's passed)
The first value in the tuple is hash'd and grouped into its partition (default)
"""

rdd_custom_partition = rdd_zipcodes_keyed.partitionBy(7)

# %%
"""
7 is the modulo by which data partitions are grouped (if this is the only argument that's passed)
The first value in the tuple is hash'd and grouped into its partition (default)
Bypass default hash'ing by passing custom hash-partitioning logic as 2nd argument
.partitionBy() uses pyspark.rdd.portable_hash() by default
"""

rdd_custom_partition = rdd_zipcodes_keyed.partitionBy(10, lambda x: hash(x))

# %%
rdd_custom_partition.getNumPartitions()
# Out:
# 10

# %%
rdd_custom_partition
# Out:
# MapPartitionsRDD[250] at mapPartitions at PythonRDD.scala:133

# %%
rdd_custom_partition.glom().take(1)
# Out:
# [[('01001',
#    ('01001', 'Agawam', 'MA', 'HAMPDEN', '', '42.140549', '-72.788661')),
#   ('01008',
#    ('01008', 'Blandford', 'MA', 'HAMPDEN', '', '42.177833', '-72.958359')),
#   ('01026',
#    ('01026', 'Cummington', 'MA', 'HAMPSHIRE', '', '42.428617', '-72.909841')),
#   ('01056',
#    ('01056', 'Ludlow', 'MA', 'HAMPDEN', '', '42.173276', '-72.627038')),
#   ('01066',
#    ('01066',
#     'North Hatfield',
#     'MA',
#     'HAMPSHIRE',
#     '',
#     '42.406697',
#     '-72.633901')),
#   ('01079',
#    ('01079', 'Thorndike', 'MA', 'HAMPDEN', '', '42.192892', '-72.329574')),
#   ('01095',
#    ('01095', 'Wilbraham', 'MA', 'HAMPDEN', '', '42.125974', '-72.489988')),
#   ('01097',
#    ('01097', 'Woronoco', 'MA', 'HAMPDEN', '', '42.161743', '-72.845912')),
#   ('01129',
#    ('01129', 'Springfield', 'MA', 'HAMPDEN', '', '42.124485', '-72.489479')),
#   ('01139',
#    ('01139', 'Springfield', 'MA', 'HAMPDEN', '', '42.170731', '-72.604842')),
#   ('01144',
#    ('01144', 'Springfield', 'MA', 'HAMPDEN', '', '42.101796', '-72.59151')),
#   ('01152',
#    ('01152', 'Springfield', 'MA', 'HAMPDEN', '', '42.170731', '-72.604842')),
#   ('01199',
#    ('01199', 'Springfield', 'MA', 'HAMPDEN', '', '42.119943', '-72.604983')),
#   ('01237',
#    ('01237', 'Lanesboro', 'MA', 'BERKSHIRE', '', '42.487569', '-73.235048')),
#   ('01243',
#    ('01243', 'Middlefield', 'MA', 'HAMPSHIRE', '', '42.356088', '-73.010448')),
#   ('01258',
#    ('01258',
#     'South Egremont',
#     'MA',
#     'BERKSHIRE',
#     '',
#     '42.128075',
#     '-73.36089')),
#   ('01338',
#    ('01338', 'Buckland', 'MA', 'FRANKLIN', '', '42.573832', '-72.769487')),
#   ('01344',
#    ('01344', 'Erving', 'MA', 'FRANKLIN', '', '42.627072', '-72.553654')),
#   ('01350',
#    ('01350',
#     'Monroe Bridge',
#     'MA',
#     'FRANKLIN',
#     '',
#     '42.721456',
#     '-72.976204')),
#   ('01378',
#    ('01378', 'Warwick', 'MA', 'FRANKLIN', '', '42.667059', '-72.339655')),
#   ('01430',
#    ('01430', 'Ashburnham', 'MA', 'WORCESTER', '', '42.654906', '-71.920942')),
#   ('01431',
#    ('01431', 'Ashby', 'MA', 'MIDDLESEX', '', '42.446396', '-71.459405')),
#   ('01451',
#    ('01451', 'Harvard', 'MA', 'WORCESTER', '', '42.500187', '-71.575864')),
#   ('01523',
#    ('01523', 'Lancaster', 'MA', 'WORCESTER', '', '42.427188', '-71.91177')),
#   ('01525',
#    ('01525', 'Linwood', 'MA', 'WORCESTER', '', '42.364807', '-71.896868')),
#   ('01526',
#    ('01526', 'Manchaug', 'MA', 'WORCESTER', '', '42.364807', '-71.896868')),
#   ('01529',
#    ('01529', 'Millville', 'MA', 'WORCESTER', '', '42.124662', '-71.846943')),
#   ('01540',
#    ('01540', 'Oxford', 'MA', 'WORCESTER', '', '42.109223', '-71.855444')),
#   ('01546',
#    ('01546', 'Shrewsbury', 'MA', 'WORCESTER', '', '42.364807', '-71.896868')),
#   ('01550',
#    ('01550', 'Southbridge', 'MA', 'WORCESTER', '', '42.129251', '-72.031155')),
#   ('01566',
#    ('01566', 'Sturbridge', 'MA', 'WORCESTER', '', '42.10273', '-72.080996')),
#   ('01569',
#    ('01569', 'Uxbridge', 'MA', 'WORCESTER', '', '42.059736', '-71.638438')),
#   ('01590',
#    ('01590', 'Sutton', 'MA', 'WORCESTER', '', '42.126575', '-71.755193')),
#   ('01602',
#    ('01602', 'Worcester', 'MA', 'WORCESTER', '', '42.274595', '-71.846966')),
#   ('01612',
#    ('01612', 'Paxton', 'MA', 'WORCESTER', '', '42.304675', '-71.892875')),
#   ('01653',
#    ('01653', 'Worcester', 'MA', 'WORCESTER', '', '42.364807', '-71.896868')),
#   ('01721',
#    ('01721', 'Ashland', 'MA', 'MIDDLESEX', '', '42.446396', '-71.459405')),
#   ('01730',
#    ('01730', 'Bedford', 'MA', 'MIDDLESEX', '', '42.446396', '-71.459405')),
#   ('01746',
#    ('01746', 'Holliston', 'MA', 'MIDDLESEX', '', '42.446396', '-71.459405')),
#   ('01756',
#    ('01756', 'Mendon', 'MA', 'WORCESTER', '', '42.100352', '-71.546961')),
#   ('01808',
#    ('01808', 'Woburn', 'MA', 'MIDDLESEX', '', '42.446396', '-71.459405')),
#   ('01832',
#    ('01832', 'Haverhill', 'MA', 'ESSEX', '', '42.789627', '-71.126562')),
#   ('01840',
#    ('01840', 'Lawrence', 'MA', 'ESSEX', '', '42.70734', '-71.161052')),
#   ('01860', ('01860', 'Merrimac', 'MA', 'ESSEX', '', '42.802441', '-71.0896')),
#   ('01885',
#    ('01885', 'West Boxford', 'MA', 'ESSEX', '', '42.635443', '-70.879123')),
#   ('01915',
#    ('01915', 'Beverly', 'MA', 'ESSEX', '', '42.565145', '-70.853843')),
#   ('01921',
#    ('01921', 'Boxford', 'MA', 'ESSEX', '', '42.683256', '-71.017403')),
#   ('01938', ('01938', 'Ipswich', 'MA', 'ESSEX', '', '42.68571', '-70.864132')),
#   ('01961',
#    ('01961', 'Peabody', 'MA', 'ESSEX', '', '42.635443', '-70.879123')),
#   ('02025',
#    ('02025', 'Cohasset', 'MA', 'NORFOLK', '', '42.233938', '-70.815826')),
#   ('02059',
#    ('02059',
#     'North Marshfield',
#     'MA',
#     'PLYMOUTH',
#     '',
#     '41.970474',
#     '-70.701357')),
#   ('02108',
#    ('02108', 'Boston', 'MA', 'SUFFOLK', '', '42.353806', '-71.102446')),
#   ('02110',
#    ('02110', 'Boston', 'MA', 'SUFFOLK', '', '42.352847', '-71.051466')),
#   ('02124',
#    ('02124', 'Boston', 'MA', 'SUFFOLK', '', '42.286784', '-71.071045')),
#   ('02133',
#    ('02133', 'Boston', 'MA', 'SUFFOLK', '', '42.338947', '-70.919635')),
#   ('02149',
#    ('02149', 'Everett', 'MA', 'MIDDLESEX', '', '42.407396', '-71.051183')),
#   ('02153',
#    ('02153', 'Medford', 'MA', 'MIDDLESEX', '', '42.446396', '-71.459405')),
#   ('02156',
#    ('02156',
#     'West Medford',
#     'MA',
#     'MIDDLESEX',
#     '',
#     '42.446396',
#     '-71.459405')),
#   ('02163',
#    ('02163', 'Boston', 'MA', 'SUFFOLK', '', '42.32532', '-71.112159')),
#   ('02169',
#    ('02169', 'Quincy', 'MA', 'NORFOLK', '', '42.241799', '-71.006042')),
#   ('02184',
#    ('02184', 'Braintree', 'MA', 'NORFOLK', '', '42.202216', '-71.005192')),
#   ('02206',
#    ('02206', 'Boston', 'MA', 'SUFFOLK', '', '42.338947', '-70.919635')),
#   ('02207',
#    ('02207', 'Boston', 'MA', 'SUFFOLK', '', '42.338947', '-70.919635')),
#   ('02211',
#    ('02211', 'Boston', 'MA', 'SUFFOLK', '', '42.338947', '-70.919635')),
#   ('02284',
#    ('02284', 'Boston', 'MA', 'SUFFOLK', '', '42.338947', '-70.919635')),
#   ('02295',
#    ('02295', 'Boston', 'MA', 'SUFFOLK', '', '42.338947', '-70.919635')),
#   ('02338',
#    ('02338', 'Halifax', 'MA', 'PLYMOUTH', '', '41.988351', '-70.860578')),
#   ('02341',
#    ('02341', 'Hanson', 'MA', 'PLYMOUTH', '', '42.055701', '-70.875936')),
#   ('02343',
#    ('02343', 'Holbrook', 'MA', 'NORFOLK', '', '42.144424', '-71.00289')),
#   ('02348',
#    ('02348', 'Middleboro', 'MA', 'PLYMOUTH', '', '41.970474', '-70.701357')),
#   ('02349',
#    ('02349', 'Middleboro', 'MA', 'PLYMOUTH', '', '41.970474', '-70.701357')),
#   ('02382',
#    ('02382', 'Whitman', 'MA', 'PLYMOUTH', '', '42.0785', '-70.940837')),
#   ('02454',
#    ('02454', 'Waltham', 'MA', 'MIDDLESEX', '', '42.356719', '-71.250479')),
#   ('02460',
#    ('02460', 'Newtonville', 'MA', 'MIDDLESEX', '', '42.374296', '-71.182371')),
#   ('02461',
#    ('02461',
#     'Newton Highlands',
#     'MA',
#     'MIDDLESEX',
#     '',
#     '42.361196',
#     '-71.205349')),
#   ('02532',
#    ('02532',
#     'Buzzards Bay',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.745505',
#     '-70.590471')),
#   ('02563',
#    ('02563', 'Sandwich', 'MA', 'BARNSTABLE', '', '41.711291', '-70.477482')),
#   ('02565',
#    ('02565',
#     'Silver Beach',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.799312',
#     '-70.308662')),
#   ('02636',
#    ('02636',
#     'Centerville',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.799312',
#     '-70.308662')),
#   ('02661',
#    ('02661',
#     'South Harwich',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.686205',
#     '-70.032858')),
#   ('02664',
#    ('02664',
#     'South Yarmouth',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.82412',
#     '-70.084259')),
#   ('02672',
#    ('02672',
#     'West Hyannisport',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.635635',
#     '-70.323307')),
#   ('02673',
#    ('02673',
#     'West Yarmouth',
#     'MA',
#     'BARNSTABLE',
#     '',
#     '41.776105',
#     '-70.150512')),
#   ('02718',
#    ('02718', 'East Taunton', 'MA', 'BRISTOL', '', '41.871407', '-71.013148')),
#   ('02738',
#    ('02738', 'Marion', 'MA', 'PLYMOUTH', '', '41.736735', '-70.754015')),
#   ('02802',
#    ('02802', 'Albion', 'RI', 'PROVIDENCE', '', '41.954098', '-71.462053')),
#   ('02813',
#    ('02813', 'Charlestown', 'RI', 'WASHINGTON', '', '41.395079', '-71.66542')),
#   ('02827', ('02827', 'Greene', 'RI', 'KENT', '', '41.691676', '-71.727467')),
#   ('02841',
#    ('02841', 'Newport', 'RI', 'NEWPORT', '', '41.498977', '-71.299004')),
#   ('02865',
#    ('02865', 'Lincoln', 'RI', 'PROVIDENCE', '', '41.925298', '-71.493355')),
#   ('02871',
#    ('02871', 'Portsmouth', 'RI', 'NEWPORT', '', '41.58523', '-71.264197')),
#   ('02912',
#    ('02912', 'Providence', 'RI', 'PROVIDENCE', '', '41.826737', '-71.397699')),
#   ('03038',
#    ('03038', 'Derry', 'NH', 'ROCKINGHAM', '', '42.950825', '-71.197169')),
#   ('03063',
#    ('03063', 'Nashua', 'NH', 'HILLSBOROUGH', '', '42.774427', '-71.511111')),
#   ('03064',
#    ('03064', 'Nashua', 'NH', 'HILLSBOROUGH', '', '42.774237', '-71.628611')),
#   ('03073',
#    ('03073',
#     'North Salem',
#     'NH',
#     'ROCKINGHAM',
#     '',
#     '43.005895',
#     '-71.013202')),
#   ('03087',
#    ('03087', 'Windham', 'NH', 'ROCKINGHAM', '', '42.892211', '-71.234009')),
#   ('03217',
#    ('03217', 'Ashland', 'NH', 'GRAFTON', '', '43.715626', '-71.639896')),
#   ('03221',
#    ('03221', 'Bradford', 'NH', 'MERRIMACK', '', '43.280961', '-71.792489')),
#   ('03225',
#    ('03225',
#     'Center Barnstead',
#     'NH',
#     'BELKNAP',
#     '',
#     '43.386652',
#     '-71.292981')),
#   ('03230',
#    ('03230', 'Danbury', 'NH', 'MERRIMACK', '', '43.514791', '-71.882094')),
#   ('03233',
#    ('03233', 'Elkins', 'NH', 'MERRIMACK', '', '43.422706', '-71.944794')),
#   ('03234',
#    ('03234', 'Epsom', 'NH', 'MERRIMACK', '', '43.340736', '-71.669712')),
#   ('03262',
#    ('03262',
#     'North Woodstock',
#     'NH',
#     'GRAFTON',
#     '',
#     '44.035391',
#     '-71.686326')),
#   ('03274',
#    ('03274', 'Stinson Lake', 'NH', 'GRAFTON', '', '43.967542', '-71.840883')),
#   ('03289',
#    ('03289', 'Winnisquam', 'NH', 'BELKNAP', '', '43.496372', '-71.519728')),
#   ('03448',
#    ('03448', 'Gilsum', 'NH', 'CHESHIRE', '', '42.936786', '-72.210953')),
#   ('03462',
#    ('03462', 'Spofford', 'NH', 'CHESHIRE', '', '42.870716', '-72.239432')),
#   ('03465',
#    ('03465', 'Troy', 'NH', 'CHESHIRE', '', '42.843617', '-72.279814')),
#   ('03574',
#    ('03574', 'Bethlehem', 'NH', 'GRAFTON', '', '44.30632', '-71.728049')),
#   ('03597',
#    ('03597',
#     'West Stewartstown',
#     'NH',
#     'COOS',
#     '',
#     '44.695648',
#     '-71.387387')),
#   ('03608',
#    ('03608', 'Walpole', 'NH', 'CHESHIRE', '', '43.072239', '-72.390121')),
#   ('03609',
#    ('03609',
#     'North Walpole',
#     'NH',
#     'CHESHIRE',
#     '',
#     '43.138018',
#     '-72.407236')),
#   ('03741',
#    ('03741', 'Canaan', 'NH', 'GRAFTON', '', '43.63123', '-72.057312')),
#   ('03765',
#    ('03765', 'Haverhill', 'NH', 'GRAFTON', '', '44.037549', '-72.046692')),
#   ('03773',
#    ('03773', 'Newport', 'NH', 'SULLIVAN', '', '43.390485', '-72.199659')),
#   ('03781',
#    ('03781', 'Plainfield', 'NH', 'SULLIVAN', '', '43.432999', '-72.282596')),
#   ('03809',
#    ('03809', 'Alton', 'NH', 'BELKNAP', '', '43.462586', '-71.222455')),
#   ('03811',
#    ('03811', 'Atkinson', 'NH', 'ROCKINGHAM', '', '42.878366', '-71.159035')),
#   ('03815',
#    ('03815',
#     'Center Strafford',
#     'NH',
#     'STRAFFORD',
#     '',
#     '43.253739',
#     '-71.109825')),
#   ('03816',
#    ('03816',
#     'Center Tuftonboro',
#     'NH',
#     'CARROLL',
#     '',
#     '43.660752',
#     '-71.274458')),
#   ('03818', ('03818', 'Conway', 'NH', 'CARROLL', '', '43.78892', '-71.10261')),
#   ('03825',
#    ('03825', 'Barrington', 'NH', 'STRAFFORD', '', '43.29779', '-71.097423')),
#   ('03844',
#    ('03844',
#     'Hampton Falls',
#     'NH',
#     'ROCKINGHAM',
#     '',
#     '42.891888',
#     '-70.982601')),
#   ('03873',
#    ('03873', 'Sandown', 'NH', 'ROCKINGHAM', '', '42.922666', '-71.174262')),
#   ('03884',
#    ('03884', 'Strafford', 'NH', 'STRAFFORD', '', '43.256871', '-71.171886')),
#   ('03901', ('03901', 'Berwick', 'ME', 'YORK', '', '43.279539', '-70.740013')),
#   ('04034',
#    ('04034', 'Freeport', 'ME', 'CUMBERLAND', '', '44.408078', '-70.470703')),
#   ('04053',
#    ('04053', 'Merepoint', 'ME', 'CUMBERLAND', '', '44.408078', '-70.470703')),
#   ('04082',
#    ('04082',
#     'South Windham',
#     'ME',
#     'CUMBERLAND',
#     '',
#     '44.408078',
#     '-70.470703')),
#   ('04092',
#    ('04092', 'Westbrook', 'ME', 'CUMBERLAND', '', '43.855116', '-70.568534')),
#   ('04103',
#    ('04103', 'Portland', 'ME', 'CUMBERLAND', '', '43.68826', '-70.289844')),
#   ('04219',
#    ('04219', 'Bryant Pond', 'ME', 'OXFORD', '', '44.265009', '-70.587095')),
#   ('04224',
#    ('04224', 'Dixfield', 'ME', 'OXFORD', '', '44.553968', '-70.422541')),
#   ('04228',
#    ('04228',
#     'East Livermore',
#     'ME',
#     'ANDROSCOGGIN',
#     '',
#     '44.197009',
#     '-70.239485')),
#   ('04261', ('04261', 'Newry', 'ME', 'OXFORD', '', '44.689526', '-71.011246')),
#   ('04266',
#    ('04266',
#     'North Turner',
#     'ME',
#     'ANDROSCOGGIN',
#     '',
#     '44.357987',
#     '-70.255783')),
#   ('04278',
#    ('04278', 'Rumford Center', 'ME', 'OXFORD', '', '44.377031', '-70.568041')),
#   ('04288',
#    ('04288',
#     'West Minot',
#     'ME',
#     'ANDROSCOGGIN',
#     '',
#     '44.197009',
#     '-70.239485')),
#   ('04336',
#    ('04336', 'Augusta', 'ME', 'KENNEBEC', '', '44.315693', '-69.818009')),
#   ('04351',
#    ('04351', 'Manchester', 'ME', 'KENNEBEC', '', '44.358014', '-69.867001')),
#   ('04406',
#    ('04406', 'Abbot', 'ME', 'PISCATAQUIS', '', '45.184103', '-69.233382')),
#   ('04413',
#    ('04413', 'Brookton', 'ME', 'WASHINGTON', '', '45.002969', '-67.495548')),
#   ('04416',
#    ('04416', 'Bucksport', 'ME', 'HANCOCK', '', '44.600448', '-68.773241')),
#   ('04417',
#    ('04417', 'Burlington', 'ME', 'PENOBSCOT', '', '44.81782', '-68.817481')),
#   ('04419',
#    ('04419', 'Carmel', 'ME', 'PENOBSCOT', '', '44.808062', '-68.940624')),
#   ('04457',
#    ('04457', 'Lincoln', 'ME', 'PENOBSCOT', '', '45.366794', '-68.49299')),
#   ('04460',
#    ('04460', 'Medway', 'ME', 'PENOBSCOT', '', '45.618608', '-68.543602')),
#   ('04471',
#    ('04471', 'Orient', 'ME', 'AROOSTOOK', '', '46.516166', '-68.886826')),
#   ('04485',
#    ('04485',
#     'Shirley Mills',
#     'ME',
#     'PISCATAQUIS',
#     '',
#     '45.792364',
#     '-69.30463')),
#   ('04544',
#    ('04544', 'East Boothbay', 'ME', 'LINCOLN', '', '43.82677', '-69.597446')),
#   ('04549',
#    ('04549',
#     'Isle Of Springs',
#     'ME',
#     'LINCOLN',
#     '',
#     '44.021333',
#     '-69.523263')),
#   ('04564',
#    ('04564', 'Round Pond', 'ME', 'LINCOLN', '', '43.932449', '-69.468052')),
#   ('04611',
#    ('04611', 'Beals', 'ME', 'WASHINGTON', '', '45.002969', '-67.495548')),
#   ('04612',
#    ('04612', 'Bernard', 'ME', 'HANCOCK', '', '44.239876', '-68.354598')),
#   ('04626',
#    ('04626', 'Cutler', 'ME', 'WASHINGTON', '', '45.002969', '-67.495548')),
#   ('04640',
#    ('04640', 'Hancock', 'ME', 'HANCOCK', '', '44.641873', '-68.391481')),
#   ('04643',
#    ('04643', 'Harrington', 'ME', 'WASHINGTON', '', '45.002969', '-67.495548')),
#   ('04645',
#    ('04645', 'Isle Au Haut', 'ME', 'KNOX', '', '44.032196', '-69.148017')),
#   ('04650',
#    ('04650',
#     'Little Deer Isle',
#     'ME',
#     'HANCOCK',
#     '',
#     '44.641873',
#     '-68.391481')),
#   ('04652',
#    ('04652', 'Lubec', 'ME', 'WASHINGTON', '', '44.904288', '-67.040767')),
#   ('04665',
#    ('04665', 'Otter Creek', 'ME', 'HANCOCK', '', '44.641873', '-68.391481')),
#   ('04671',
#    ('04671', 'Robbinston', 'ME', 'WASHINGTON', '', '45.002969', '-67.495548')),
#   ('04672',
#    ('04672', 'Salsbury Cove', 'ME', 'HANCOCK', '', '44.413523', '-68.251778')),
#   ('04683',
#    ('04683', 'Sunset', 'ME', 'HANCOCK', '', '44.641873', '-68.391481')),
#   ('04739',
#    ('04739', 'Eagle Lake', 'ME', 'AROOSTOOK', '', '46.516166', '-68.886826')),
#   ('04759',
#    ('04759', 'Masardis', 'ME', 'AROOSTOOK', '', '46.516166', '-68.886826')),
#   ('04772',
#    ('04772',
#     'Saint Agatha',
#     'ME',
#     'AROOSTOOK',
#     '',
#     '47.263956',
#     '-68.335025')),
#   ('04851',
#    ('04851', 'Matinicus', 'ME', 'KNOX', '', '44.032196', '-69.148017')),
#   ('04852',
#    ('04852', 'Monhegan', 'ME', 'LINCOLN', '', '44.021333', '-69.523263')),
#   ('04912', ('04912', 'Athens', 'ME', 'SOMERSET', '', '44.9227', '-69.67668')),
#   ('04921', ('04921', 'Brooks', 'ME', 'WALDO', '', '44.579387', '-69.175448')),
#   ('04923',
#    ('04923', 'Cambridge', 'ME', 'SOMERSET', '', '45.036055', '-69.438697')),
#   ('04954',
#    ('04954', 'New Portland', 'ME', 'SOMERSET', '', '45.575731', '-69.909773')),
#   ('04961',
#    ('04961',
#     'North New Portland',
#     'ME',
#     'SOMERSET',
#     '',
#     '45.575731',
#     '-69.909773')),
#   ('04985',
#    ('04985', 'West Forks', 'ME', 'SOMERSET', '', '45.575731', '-69.909773')),
#   ('05034',
#    ('05034', 'Bridgewater', 'VT', 'WINDSOR', '', '43.592527', '-72.621578')),
#   ('05046',
#    ('05046', 'Groton', 'VT', 'CALEDONIA', '', '44.281506', '-72.207573')),
#   ('05055',
#    ('05055', 'Norwich', 'VT', 'WINDSOR', '', '43.717918', '-72.3612')),
#   ('05061',
#    ('05061',
#     'Randolph Center',
#     'VT',
#     'ORANGE',
#     '',
#     '43.928552',
#     '-72.569113')),
#   ('05067',
#    ('05067', 'South Pomfret', 'VT', 'WINDSOR', '', '43.697055', '-72.508042')),
#   ('05251',
#    ('05251', 'Dorset', 'VT', 'BENNINGTON', '', '43.261817', '-73.139173')),
#   ('05253',
#    ('05253',
#     'East Dorset',
#     'VT',
#     'BENNINGTON',
#     '',
#     '43.182502',
#     '-73.065443')),
#   ('05262',
#    ('05262', 'Shaftsbury', 'VT', 'BENNINGTON', '', '42.979702', '-73.192929')),
#   ('05304',
#    ('05304', 'Brattleboro', 'VT', 'WINDHAM', '', '42.99467', '-72.720362')),
#   ('05346',
#    ('05346', 'Putney', 'VT', 'WINDHAM', '', '43.016096', '-72.534025')),
#   ('05359',
#    ('05359',
#     'West Townshend',
#     'VT',
#     'WINDHAM',
#     '',
#     '43.133864',
#     '-72.714573')),
#   ('05402',
#    ('05402', 'Burlington', 'VT', 'CHITTENDEN', '', '44.442117', '-73.082525')),
#   ('05439',
#    ('05439', 'Colchester', 'VT', 'CHITTENDEN', '', '44.49518', '-73.165092')),
#   ('05440',
#    ('05440', 'Alburg', 'VT', 'GRAND ISLE', '', '44.93606', '-73.289065')),
#   ('05443',
#    ('05443', 'Bristol', 'VT', 'ADDISON', '', '44.157814', '-73.071813')),
#   ('05468',
#    ('05468', 'Milton', 'VT', 'CHITTENDEN', '', '44.643418', '-73.121685')),
#   ('05471',
#    ('05471',
#     'Montgomery Center',
#     'VT',
#     'FRANKLIN',
#     '',
#     '44.848241',
#     '-72.619812')),
#   ('05476',
#    ('05476', 'Richford', 'VT', 'FRANKLIN', '', '44.952669', '-72.65435')),
#   ('05651',
#    ('05651',
#     'East Montpelier',
#     'VT',
#     'WASHINGTON',
#     '',
#     '44.279376',
#     '-72.49657')),
#   ('05652', ('05652', 'Eden', 'VT', 'LAMOILLE', '', '44.718619', '-72.57821')),
#   ('05658',
#    ('05658', 'Marshfield', 'VT', 'WASHINGTON', '', '44.374874', '-72.329902')),
#   ('05739', ('05739', 'Danby', 'VT', 'RUTLAND', '', '43.34792', '-73.027985')),
#   ('05740',
#    ('05740',
#     'East Middlebury',
#     'VT',
#     'ADDISON',
#     '',
#     '43.97153',
#     '-73.091416')),
#   ('05741',
#    ('05741', 'East Poultney', 'VT', 'RUTLAND', '', '43.592039', '-72.818121')),
#   ('05748',
#    ('05748', 'Hancock', 'VT', 'ADDISON', '', '43.907858', '-72.890031')),
#   ('05767',
#    ('05767', 'Rochester', 'VT', 'WINDSOR', '', '43.866832', '-72.851495')),
#   ('05823',
#    ('05823', 'Beebe Plain', 'VT', 'ORLEANS', '', '45.005783', '-72.138347')),
#   ('05843',
#    ('05843', 'Hardwick', 'VT', 'CALEDONIA', '', '44.51609', '-72.309822')),
#   ('05858',
#    ('05858', 'North Concord', 'VT', 'ESSEX', '', '44.512087', '-71.795986')),
#   ('05862',
#    ('05862', 'Peacham', 'VT', 'CALEDONIA', '', '44.46239', '-72.135804')),
#   ('05866',
#    ('05866', 'Sheffield', 'VT', 'CALEDONIA', '', '44.639653', '-72.132255')),
#   ('05907', ('05907', 'Norton', 'VT', 'ESSEX', '', '44.932643', '-71.776359')),
#   ('06019',
#    ('06019', 'Canton', 'CT', 'HARTFORD', '', '41.842882', '-72.899645')),
#   ('06034',
#    ('06034', 'Farmington', 'CT', 'HARTFORD', '', '41.791776', '-72.718832')),
#   ('06064',
#    ('06064', 'Poquonock', 'CT', 'HARTFORD', '', '41.791776', '-72.718832')),
#   ('06080',
#    ('06080', 'Suffield', 'CT', 'HARTFORD', '', '41.948597', '-72.628802')),
#   ('06089',
#    ('06089', 'Weatogue', 'CT', 'HARTFORD', '', '41.889965', '-72.704')),
#   ('06115',
#    ('06115', 'Hartford', 'CT', 'HARTFORD', '', '41.758849', '-72.679387')),
#   ('06126',
#    ('06126', 'Hartford', 'CT', 'HARTFORD', '', '41.791776', '-72.718832')),
#   ('06150',
#    ('06150', 'Hartford', 'CT', 'HARTFORD', '', '41.791776', '-72.718832')),
#   ('06180',
#    ('06180', 'Hartford', 'CT', 'HARTFORD', '', '41.791776', '-72.718832')),
#   ('06183',
#    ('06183', 'Hartford', 'CT', 'HARTFORD', '', '41.763849', '-72.673037')),
#   ('06233',
#    ('06233', 'Ballouville', 'CT', 'WINDHAM', '', '41.831565', '-72.020137')),
#   ('06249',
#    ('06249', 'Lebanon', 'CT', 'NEW LONDON', '', '41.628008', '-72.245422')),
#   ('06265',
#    ('06265',
#     'South Willington',
#     'CT',
#     'TOLLAND',
#     '',
#     '41.81152',
#     '-72.308779')),
#   ('06279',
#    ('06279', 'Willington', 'CT', 'TOLLAND', '', '41.896623', '-72.262236')),
#   ('06281',
#    ('06281', 'Woodstock', 'CT', 'WINDHAM', '', '41.961991', '-72.014108')),
#   ('06332',
#    ('06332',
#     'Central Village',
#     'CT',
#     'WINDHAM',
#     '',
#     '41.725694',
#     '-71.909019')),
#   ('06338',
#    ('06338', 'Mashantucket', 'CT', 'NEW LONDON', '', '41.47', '-71.95')),
#   ('06380',
#    ('06380', 'Taftville', 'CT', 'NEW LONDON', '', '41.563998', '-72.05522')),
#   ('06386',
#    ('06386', 'Waterford', 'CT', 'NEW LONDON', '', '41.464758', '-72.127301')),
#   ('06412',
#    ('06412', 'Chester', 'CT', 'MIDDLESEX', '', '41.39027', '-72.461805')),
#   ('06438',
#    ('06438', 'Haddam', 'CT', 'MIDDLESEX', '', '41.471457', '-72.511376')),
#   ('06439',
#    ('06439', 'Hadlyme', 'CT', 'NEW LONDON', '', '41.421198', '-72.414095')),
#   ('06441',
#    ('06441', 'Higganum', 'CT', 'MIDDLESEX', '', '41.462718', '-72.578971')),
#   ('06467',
#    ('06467', 'Milldale', 'CT', 'HARTFORD', '', '41.565697', '-72.903746')),
#   ('06514',
#    ('06514', 'Hamden', 'CT', 'NEW HAVEN', '', '41.372723', '-72.938747')),
#   ('06517',
#    ('06517', 'Hamden', 'CT', 'NEW HAVEN', '', '41.362197', '-72.911396')),
#   ('06520',
#    ('06520', 'New Haven', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06521',
#    ('06521', 'New Haven', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06530',
#    ('06530', 'New Haven', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06532',
#    ('06532', 'New Haven', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06533',
#    ('06533', 'New Haven', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06606',
#    ('06606', 'Bridgeport', 'CT', 'FAIRFIELD', '', '41.208796', '-73.211807')),
#   ('06608',
#    ('06608', 'Bridgeport', 'CT', 'FAIRFIELD', '', '41.188199', '-73.180005')),
#   ('06702',
#    ('06702', 'Waterbury', 'CT', 'NEW HAVEN', '', '41.540696', '-73.071124')),
#   ('06723',
#    ('06723', 'Waterbury', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06725',
#    ('06725', 'Waterbury', 'CT', 'NEW HAVEN', '', '41.365709', '-72.927507')),
#   ('06756',
#    ('06756', 'Goshen', 'CT', 'LITCHFIELD', '', '41.794278', '-73.239023')),
#   ('06777',
#    ('06777',
#     'New Preston Marble Dale',
#     'CT',
#     'LITCHFIELD',
#     '',
#     '41.690297',
#     '-73.310346')),
#   ('06785',
#    ('06785', 'South Kent', 'CT', 'LITCHFIELD', '', '41.682439', '-73.305256')),
#   ('06786',
#    ('06786', 'Terryville', 'CT', 'LITCHFIELD', '', '41.66353', '-73.022449')),
#   ('06791',
#    ('06791', 'Harwinton', 'CT', 'LITCHFIELD', '', '41.649639', '-73.176163')),
#   ('06876',
#    ('06876',
#     'Redding Ridge',
#     'CT',
#     'FAIRFIELD',
#     '',
#     '41.032647',
#     '-73.583569')),
#   ('06877',
#    ('06877', 'Ridgefield', 'CT', 'FAIRFIELD', '', '41.308201', '-73.494637')),
#   ('06928',
#    ('06928', 'Stamford', 'CT', 'FAIRFIELD', '', '41.308873', '-73.363661')),
#   ('07010',
#    ('07010', 'Cliffside Park', 'NJ', 'BERGEN', '', '40.820541', '-73.98782')),
#   ('07043', ('07043', 'Montclair', 'NJ', 'ESSEX', '', '40.8034', '-74.19448')),
#   ('07076',
#    ('07076', 'Scotch Plains', 'NJ', 'UNION', '', '40.637852', '-74.368244')),
#   ('07080',
#    ('07080',
#     'South Plainfield',
#     'NJ',
#     'MIDDLESEX',
#     '',
#     '40.572065',
#     '-74.413545')),
#   ('07099', ('07099', 'Kearny', 'NJ', 'HUDSON', '', '40.73276', '-74.075485')),
#   ('07102', ('07102', 'Newark', 'NJ', 'ESSEX', '', '40.735642', '-74.173988')),
#   ('07108', ('07108', 'Newark', 'NJ', 'ESSEX', '', '40.722496', '-74.200649')),
#   ('07193', ('07193', 'Newark', 'NJ', 'ESSEX', '', '40.79185', '-74.245241')),
#   ('07197', ('07197', 'Newark', 'NJ', 'ESSEX', '', '40.79185', '-74.245241')),
#   ('07199', ('07199', 'Newark', 'NJ', 'ESSEX', '', '40.79185', '-74.245241')),
#   ('07202',
#    ('07202', 'Elizabeth', 'NJ', 'UNION', '', '40.650902', '-74.217189')),
#   ('07204',
#    ('07204', 'Roselle Park', 'NJ', 'UNION', '', '40.665652', '-74.26674')),
#   ('07435',
#    ('07435', 'Newfoundland', 'NJ', 'PASSAIC', '', '41.053096', '-74.439356')),
#   ('07442',
#    ('07442', 'Pompton Lakes', 'NJ', 'PASSAIC', '', '40.999597', '-74.297725')),
#   ('07456',
#    ('07456', 'Ringwood', 'NJ', 'PASSAIC', '', '41.110445', '-74.293271')),
#   ('07474',
#    ('07474', 'Wayne', 'NJ', 'PASSAIC', '', '41.011428', '-74.304793')),
#   ('07506',
#    ('07506', 'Hawthorne', 'NJ', 'PASSAIC', '', '40.954375', '-74.161788')),
#   ('07641',
#    ('07641', 'Haworth', 'NJ', 'BERGEN', '', '40.963867', '-73.99358')),
#   ('07656',
#    ('07656', 'Park Ridge', 'NJ', 'BERGEN', '', '41.032868', '-74.042948')),
#   ('07662',
#    ('07662', 'Rochelle Park', 'NJ', 'BERGEN', '', '40.905698', '-74.079035')),
#   ('07675',
#    ('07675', 'Westwood', 'NJ', 'BERGEN', '', '41.011453', '-74.021278')),
#   ('07702',
#    ('07702', 'Shrewsbury', 'NJ', 'MONMOUTH', '', '40.325361', '-74.107943')),
#   ('07726',
#    ('07726', 'Englishtown', 'NJ', 'MONMOUTH', '', '40.2697', '-74.265539')),
#   ('07734',
#    ('07734', 'Keansburg', 'NJ', 'MONMOUTH', '', '40.438145', '-74.127883')),
#   ('07746',
#    ('07746', 'Marlboro', 'NJ', 'MONMOUTH', '', '40.351277', '-74.141236')),
#   ('07756',
#    ('07756', 'Ocean Grove', 'NJ', 'MONMOUTH', '', '40.278922', '-74.123285')),
#   ('07828',
#    ('07828', 'Budd Lake', 'NJ', 'MORRIS', '', '40.880028', '-74.75756')),
#   ('07829',
#    ('07829', 'Buttzville', 'NJ', 'WARREN', '', '40.84335', '-74.985914')),
#   ('07847',
#    ('07847', 'Kenvil', 'NJ', 'MORRIS', '', '40.876098', '-74.695309')),
#   ('07860',
#    ('07860', 'Newton', 'NJ', 'SUSSEX', '', '41.069522', '-74.806938')),
#   ('07970',
#    ('07970', 'Mount Freedom', 'NJ', 'MORRIS', '', '40.805549', '-74.573832')),
#   ('08003',
#    ('08003', 'Cherry Hill', 'NJ', 'CAMDEN', '', '39.889763', '-74.972761')),
#   ('08009', ('08009', 'Berlin', 'NJ', 'CAMDEN', '', '39.761231', '-74.92701')),
#   ('08016',
#    ('08016', 'Burlington', 'NJ', 'BURLINGTON', '', '40.089874', '-74.751146')),
#   ('08059',
#    ('08059', 'Mount Ephraim', 'NJ', 'CAMDEN', '', '39.886463', '-75.094068')),
#   ('08063',
#    ('08063',
#     'National Park',
#     'NJ',
#     'GLOUCESTER',
#     '',
#     '39.779654',
#     '-75.218413')),
#   ('08070',
#    ('08070', 'Pennsville', 'NJ', 'SALEM', '', '39.637683', '-75.512699')),
#   ('08072',
#    ('08072', 'Quinton', 'NJ', 'SALEM', '', '39.541055', '-75.383689')),
#   ('08089',
#    ('08089',
#     'Waterford Works',
#     'NJ',
#     'CAMDEN',
#     '',
#     '39.723037',
#     '-74.836939')),
#   ('08094',
#    ('08094',
#     'Williamstown',
#     'NJ',
#     'GLOUCESTER',
#     '',
#     '39.725538',
#     '-75.058082')),
#   ('08204',
#    ('08204', 'Cape May', 'NJ', 'CAPE MAY', '', '39.110337', '-74.767939')),
#   ('08218',
#    ('08218', 'Goshen', 'NJ', 'CAPE MAY', '', '39.056521', '-74.816619')),
#   ('08310',
#    ('08310', 'Buena', 'NJ', 'ATLANTIC', '', '39.523712', '-74.899762')),
#   ('08314',
#    ('08314', 'Delmont', 'NJ', 'CUMBERLAND', '', '39.358151', '-74.977352')),
#   ('08323',
#    ('08323', 'Greenwich', 'NJ', 'CUMBERLAND', '', '39.405498', '-75.320881')),
#   ('08327',
#    ('08327', 'Leesburg', 'NJ', 'CUMBERLAND', '', '39.387948', '-75.007418')),
#   ('08349',
#    ('08349',
#     'Port Norris',
#     'NJ',
#     'CUMBERLAND',
#     '',
#     '39.283259',
#     '-75.098448')),
#   ('08350',
#    ('08350', 'Richland', 'NJ', 'ATLANTIC', '', '39.491351', '-74.875543')),
#   ('08352',
#    ('08352', 'Rosenhayn', 'NJ', 'CUMBERLAND', '', '39.469515', '-75.146176')),
#   ('08526',
#    ('08526', 'Imlaystown', 'NJ', 'MONMOUTH', '', '40.162275', '-74.475936')),
#   ('08527',
#    ('08527', 'Jackson', 'NJ', 'OCEAN', '', '40.105164', '-74.352814')),
#   ('08554',
#    ('08554', 'Roebling', 'NJ', 'BURLINGTON', '', '40.071829', '-74.711814')),
#   ('08555',
#    ('08555', 'Roosevelt', 'NJ', 'MONMOUTH', '', '40.22136', '-74.474745')),
#   ('08629',
#    ('08629', 'Trenton', 'NJ', 'MERCER', '', '40.219558', '-74.733404')),
#   ('08645',
#    ('08645', 'Trenton', 'NJ', 'MERCER', '', '40.280531', '-74.712018')),
#   ('08690',
#    ('08690', 'Trenton', 'NJ', 'MERCER', '', '40.233577', '-74.657602')),
#   ('08720',
#    ('08720', 'Allenwood', 'NJ', 'MONMOUTH', '', '40.138878', '-74.11221')),
#   ('08723', ('08723', 'Brick', 'NJ', 'OCEAN', '', '39.940021', '-74.122989')),
#   ('08732',
#    ('08732', 'Island Heights', 'NJ', 'OCEAN', '', '39.983267', '-74.128482')),
#   ('08733',
#    ('08733', 'Lakehurst', 'NJ', 'OCEAN', '', '39.992317', '-74.28224')),
#   ('08734',
#    ('08734', 'Lanoka Harbor', 'NJ', 'OCEAN', '', '39.863489', '-74.168217')),
#   ('08758',
#    ('08758', 'Waretown', 'NJ', 'OCEAN', '', '39.787943', '-74.246662')),
#   ('08816',
#    ('08816',
#     'East Brunswick',
#     'NJ',
#     'MIDDLESEX',
#     '',
#     '40.427697',
#     '-74.421695')),
#   ('08823',
#    ('08823',
#     'Franklin Park',
#     'NJ',
#     'SOMERSET',
#     '',
#     '40.440604',
#     '-74.560249')),
#   ('10011',
#    ('10011', 'New York', 'NY', 'NEW YORK', '', '40.740916', '-73.999769')),
#   ('10017',
#    ('10017', 'New York', 'NY', 'NEW YORK', '', '40.752955', '-73.973196')),
#   ('10045',
#    ('10045', 'New York', 'NY', 'NEW YORK', '', '40.70859', '-74.008687')),
#   ('10080',
#    ('10080', 'New York', 'NY', 'NEW YORK', '', '40.780751', '-73.977182')),
#   ('10099',
#    ('10099', 'New York', 'NY', 'NEW YORK', '', '40.780751', '-73.977182')),
#   ('10103',
#    ('10103', 'New York', 'NY', 'NEW YORK', '', '40.760264', '-73.97624')),
#   ('10107',
#    ('10107', 'New York', 'NY', 'NEW YORK', '', '40.766429', '-73.982728')),
#   ('10108',
#    ('10108', 'New York', 'NY', 'NEW YORK', '', '40.780751', '-73.977182')),
#   ('10112',
#    ('10112', 'New York', 'NY', 'NEW YORK', '', '40.759287', '-73.979808')),
#   ('10120',
#    ('10120', 'New York', 'NY', 'NEW YORK', '', '40.750629', '-73.989426')),
#   ('10152',
#    ('10152', 'New York', 'NY', 'NEW YORK', '', '40.758937', '-73.97302')),
#   ('10167',
#    ('10167', 'New York', 'NY', 'NEW YORK', '', '40.754858', '-73.97497')),
#   ('10170',
#    ('10170', 'New York', 'NY', 'NEW YORK', '', '40.752621', '-73.97548')),
#   ('10175',
#    ('10175', 'New York', 'NY', 'NEW YORK', '', '40.754305', '-73.979782')),
#   ('10213',
#    ('10213', 'New York', 'NY', 'NEW YORK', '', '40.780751', '-73.977182')),
#   ('10269',
#    ('10269', 'New York', 'NY', 'NEW YORK', '', '40.780751', '-73.977182')),
#   ('10277',
#    ('10277', 'New York', 'NY', 'NEW YORK', '', '40.780751', '-73.977182')),
#   ('10466', ('10466', 'Bronx', 'NY', 'BRONX', '', '40.859878', '-73.841003')),
#   ('10473', ('10473', 'Bronx', 'NY', 'BRONX', '', '40.816229', '-73.860304')),
#   ('10475', ('10475', 'Bronx', 'NY', 'BRONX', '', '40.874878', '-73.827653')),
#   ('10501',
#    ('10501', 'Amawalk', 'NY', 'WESTCHESTER', '', '41.293169', '-73.759033')),
#   ('10506',
#    ('10506', 'Bedford', 'NY', 'WESTCHESTER', '', '41.123741', '-73.718481')),
#   ('10536',
#    ('10536', 'Katonah', 'NY', 'WESTCHESTER', '', '41.271614', '-73.687334')),
#   ('10562',
#    ('10562', 'Ossining', 'NY', 'WESTCHESTER', '', '41.109701', '-73.827995')),
#   ('10573',
#    ('10573',
#     'Port Chester',
#     'NY',
#     'WESTCHESTER',
#     '',
#     '41.022193',
#     '-73.679799')),
#   ('10591',
#    ('10591', 'Tarrytown', 'NY', 'WESTCHESTER', '', '41.089703', '-73.844034')),
#   ('10601',
#    ('10601',
#     'White Plains',
#     'NY',
#     'WESTCHESTER',
#     '',
#     '41.031397',
#     '-73.769626')),
#   ('10610',
#    ('10610',
#     'White Plains',
#     'NY',
#     'WESTCHESTER',
#     '',
#     '41.119008',
#     '-73.732996')),
#   ('10625',
#    ('10625',
#     'White Plains',
#     'NY',
#     'WESTCHESTER',
#     '',
#     '41.119008',
#     '-73.732996')),
#   ('10703',
#    ('10703', 'Yonkers', 'NY', 'WESTCHESTER', '', '40.959347', '-73.881329')),
#   ('10707',
#    ('10707', 'Tuckahoe', 'NY', 'WESTCHESTER', '', '40.960498', '-73.816127')),
#   ('10915',
#    ('10915', 'Bullville', 'NY', 'ORANGE', '', '41.555634', '-74.328805')),
#   ('10925',
#    ('10925', 'Greenwood Lake', 'NY', 'ORANGE', '', '41.297325', '-74.26484')),
#   ('10949', ('10949', 'Monroe', 'NY', 'ORANGE', '', '41.3', '-74.19')),
#   ('10962',
#    ('10962', 'Orangeburg', 'NY', 'ROCKLAND', '', '41.057496', '-73.953181')),
#   ('10982',
#    ('10982', 'Tallman', 'NY', 'ROCKLAND', '', '41.160945', '-74.060826')),
#   ('10983',
#    ('10983', 'Tappan', 'NY', 'ROCKLAND', '', '41.027646', '-73.948404')),
#   ('10992',
#    ('10992',
#     'Washingtonville',
#     'NY',
#     'ORANGE',
#     '',
#     '41.407974',
#     '-74.345433')),
#   ('10994',
#    ('10994', 'West Nyack', 'NY', 'ROCKLAND', '', '41.100622', '-73.970482')),
#   ('11025',
#    ('11025', 'Great Neck', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11096',
#    ('11096', 'Inwood', 'NY', 'NASSAU', '', '40.620492', '-73.747376')),
#   ('11103',
#    ('11103', 'Astoria', 'NY', 'QUEENS', '', '40.761884', '-73.911642')),
#   ('11215',
#    ('11215', 'Brooklyn', 'NY', 'KINGS', '', '40.664322', '-73.984132')),
#   ('11235',
#    ('11235', 'Brooklyn', 'NY', 'KINGS', '', '40.584455', '-73.948402')),
#   ('11245',
#    ('11245', 'Brooklyn', 'NY', 'KINGS', '', '40.645099', '-73.945032')),
#   ('11255',
#    ('11255', 'Brooklyn', 'NY', 'KINGS', '', '40.645099', '-73.945032')),
#   ('11354',
#    ('11354', 'Flushing', 'NY', 'QUEENS', '', '40.766382', '-73.82619')),
#   ('11355',
#    ('11355', 'Flushing', 'NY', 'QUEENS', '', '40.750317', '-73.813903')),
#   ('11359',
#    ('11359', 'Bayside', 'NY', 'QUEENS', '', '40.79278', '-73.776701')),
#   ('11364',
#    ('11364',
#     'Oakland Gardens',
#     'NY',
#     'QUEENS',
#     '',
#     '40.742772',
#     '-73.758831')),
#   ('11377',
#    ('11377', 'Woodside', 'NY', 'QUEENS', '', '40.748372', '-73.905445')),
#   ('11390',
#    ('11390', 'Flushing', 'NY', 'QUEENS', '', '40.651378', '-73.870779')),
#   ('11416',
#    ('11416', 'Ozone Park', 'NY', 'QUEENS', '', '40.684546', '-73.850708')),
#   ('11418',
#    ('11418', 'Richmond Hill', 'NY', 'QUEENS', '', '40.698566', '-73.83127')),
#   ('11421',
#    ('11421', 'Woodhaven', 'NY', 'QUEENS', '', '40.691917', '-73.85666')),
#   ('11422',
#    ('11422', 'Rosedale', 'NY', 'QUEENS', '', '40.659418', '-73.736866')),
#   ('11423',
#    ('11423', 'Hollis', 'NY', 'QUEENS', '', '40.716888', '-73.766897')),
#   ('11514',
#    ('11514', 'Carle Place', 'NY', 'NASSAU', '', '40.74435', '-73.608422')),
#   ('11547',
#    ('11547',
#     'Glenwood Landing',
#     'NY',
#     'NASSAU',
#     '',
#     '40.754757',
#     '-73.601772')),
#   ('11555',
#    ('11555', 'Uniondale', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11559',
#    ('11559', 'Lawrence', 'NY', 'NASSAU', '', '40.615435', '-73.72642')),
#   ('11563',
#    ('11563', 'Lynbrook', 'NY', 'NASSAU', '', '40.657602', '-73.672574')),
#   ('11568',
#    ('11568', 'Old Westbury', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11572',
#    ('11572', 'Oceanside', 'NY', 'NASSAU', '', '40.635252', '-73.636923')),
#   ('11575',
#    ('11575', 'Roosevelt', 'NY', 'NASSAU', '', '40.680451', '-73.590071')),
#   ('11576',
#    ('11576', 'Roslyn', 'NY', 'NASSAU', '', '40.656802', '-73.622523')),
#   ('11594',
#    ('11594', 'Westbury', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11704',
#    ('11704', 'West Babylon', 'NY', 'SUFFOLK', '', '40.709098', '-73.356164')),
#   ('11714',
#    ('11714', 'Bethpage', 'NY', 'NASSAU', '', '40.728449', '-73.495369')),
#   ('11715',
#    ('11715', 'Blue Point', 'NY', 'SUFFOLK', '', '40.75673', '-73.043481')),
#   ('11729',
#    ('11729', 'Deer Park', 'NY', 'SUFFOLK', '', '40.762574', '-73.323061')),
#   ('11732',
#    ('11732', 'East Norwich', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11735',
#    ('11735', 'Farmingdale', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11739',
#    ('11739', 'Great River', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#   ('11741',
#    ('11741', 'Holbrook', 'NY', 'SUFFOLK', '', '40.78791', '-73.066689')),
#   ('11757',
#    ('11757', 'Lindenhurst', 'NY', 'SUFFOLK', '', '40.688799', '-73.376475')),
#   ('11760',
#    ('11760', 'Islandia', 'NY', 'SUFFOLK', '', '40.810246', '-73.191789')),
#   ('11764',
#    ('11764', 'Miller Place', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#   ('11773',
#    ('11773', 'Syosset', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11774',
#    ('11774', 'Farmingdale', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11779',
#    ('11779', 'Ronkonkoma', 'NY', 'SUFFOLK', '', '40.808322', '-73.130469')),
#   ('11792',
#    ('11792', 'Wading River', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#   ('11803',
#    ('11803', 'Plainview', 'NY', 'NASSAU', '', '40.754757', '-73.601772')),
#   ('11939',
#    ('11939', 'East Marion', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#   ('11942',
#    ('11942', 'East Quogue', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#   ('11951',
#    ('11951', 'Mastic Beach', 'NY', 'SUFFOLK', '', '40.922326', '-72.637078')),
#   ('12007',
#    ('12007', 'Alcove', 'NY', 'ALBANY', '', '42.482455', '-73.936671')),
#   ('12022',
#    ('12022', 'Berlin', 'NY', 'RENSSELAER', '', '42.67051', '-73.357825')),
#   ('12024',
#    ('12024', 'Brainard', 'NY', 'RENSSELAER', '', '42.494981', '-73.510676')),
#   ('12043',
#    ('12043', 'Cobleskill', 'NY', 'SCHOHARIE', '', '42.665376', '-74.51884')),
#   ('12053',
#    ('12053', 'Delanson', 'NY', 'SCHENECTADY', '', '42.77788', '-74.197936')),
#   ('12063',
#    ('12063',
#     'East Schodack',
#     'NY',
#     'RENSSELAER',
#     '',
#     '42.563685',
#     '-73.627428')),
#   ('12076',
#    ('12076', 'Gilboa', 'NY', 'SCHOHARIE', '', '42.411096', '-74.427506')),
#   ('12087',
#    ('12087', 'Hannacroix', 'NY', 'GREENE', '', '42.411114', '-73.881515')),
#   ('12107', ('12107', 'Knox', 'NY', 'ALBANY', '', '42.660046', '-74.116812')),
#   ('12132',
#    ('12132',
#     'North Chatham',
#     'NY',
#     'COLUMBIA',
#     '',
#     '42.466061',
#     '-73.629296')),
#   ('12140',
#    ('12140',
#     'Poestenkill',
#     'NY',
#     'RENSSELAER',
#     '',
#     '42.686757',
#     '-73.527434')),
#   ('12157',
#    ('12157', 'Schoharie', 'NY', 'SCHOHARIE', '', '42.655569', '-74.337322')),
#   ('12167',
#    ('12167', 'Stamford', 'NY', 'DELAWARE', '', '42.413508', '-74.61939')),
#   ('12172',
#    ('12172', 'Stottville', 'NY', 'COLUMBIA', '', '42.285749', '-73.733532')),
#   ('12180',
#    ('12180', 'Troy', 'NY', 'RENSSELAER', '', '42.673701', '-73.608792')),
#   ('12207',
#    ('12207', 'Albany', 'NY', 'ALBANY', '', '42.656029', '-73.750764')),
#   ('12226',
#    ('12226', 'Albany', 'NY', 'ALBANY', '', '42.614852', '-73.970812')),
#   ('12228',
#    ('12228', 'Albany', 'NY', 'ALBANY', '', '42.614852', '-73.970812')),
#   ('12238',
#    ('12238', 'Albany', 'NY', 'ALBANY', '', '42.614852', '-73.970812')),
#   ('12252',
#    ('12252', 'Albany', 'NY', 'ALBANY', '', '42.614852', '-73.970812')),
#   ('12288',
#    ('12288', 'Albany', 'NY', 'ALBANY', '', '42.614852', '-73.970812')),
#   ('12307',
#    ('12307',
#     'Schenectady',
#     'NY',
#     'SCHENECTADY',
#     '',
#     '42.805376',
#     '-73.934868')),
#   ('12309',
#    ('12309',
#     'Schenectady',
#     'NY',
#     'SCHENECTADY',
#     '',
#     '42.809077',
#     '-73.869316')),
#   ('12345',
#    ('12345',
#     'Schenectady',
#     'NY',
#     'SCHENECTADY',
#     '',
#     '42.833261',
#     '-74.058015')),
#   ('12405', ('12405', 'Acra', 'NY', 'GREENE', '', '42.315975', '-74.065515')),
#   ('12413', ('12413', 'Cairo', 'NY', 'GREENE', '', '42.301789', '-74.029434')),
#   ('12450',
#    ('12450', 'Lanesville', 'NY', 'GREENE', '', '42.208809', '-74.163793')),
#   ('12453',
#    ('12453',
#     'Malden On Hudson',
#     'NY',
#     'ULSTER',
#     '',
#     '42.098698',
#     '-73.935418')),
#   ('12459',
#    ('12459', 'New Kingston', 'NY', 'DELAWARE', '', '42.20943', '-74.683726')),
#   ('12510',
#    ('12510', 'Billings', 'NY', 'DUTCHESS', '', '41.759905', '-73.743714')),
#   ('12516',
#    ('12516', 'Copake', 'NY', 'COLUMBIA', '', '42.099322', '-73.576102')),
#   ('12521',
#    ('12521', 'Craryville', 'NY', 'COLUMBIA', '', '42.190488', '-73.64465')),
#   ('12522',
#    ('12522', 'Dover Plains', 'NY', 'DUTCHESS', '', '41.800316', '-73.687324')),
#   ('12527',
#    ('12527', 'Glenham', 'NY', 'DUTCHESS', '', '41.520249', '-73.933259')),
#   ('12552',
#    ('12552', 'Newburgh', 'NY', 'ORANGE', '', '41.387822', '-74.354699')),
#   ('12575',
#    ('12575', 'Rock Tavern', 'NY', 'ORANGE', '', '41.50755', '-74.156394')),
#   ('12582',
#    ('12582', 'Stormville', 'NY', 'DUTCHESS', '', '41.554509', '-73.72667')),
#   ('12583',
#    ('12583', 'Tivoli', 'NY', 'DUTCHESS', '', '41.909683', '-73.749214')),
#   ('12603',
#    ('12603', 'Poughkeepsie', 'NY', 'DUTCHESS', '', '41.690707', '-73.862074')),
#   ('12701',
#    ('12701', 'Monticello', 'NY', 'SULLIVAN', '', '41.686944', '-74.677156')),
#   ('12742',
#    ('12742', 'Harris', 'NY', 'SULLIVAN', '', '41.710156', '-74.71536')),
#   ('12745',
#    ('12745', 'Hortonville', 'NY', 'SULLIVAN', '', '41.762944', '-75.030592')),
#   ('12747',
#    ('12747', 'Hurleyville', 'NY', 'SULLIVAN', '', '41.770283', '-74.726066')),
#   ('12751',
#    ('12751',
#     'Kiamesha Lake',
#     'NY',
#     'SULLIVAN',
#     '',
#     '41.694655',
#     '-74.682731')),
#   ('12778',
#    ('12778', 'Smallwood', 'NY', 'SULLIVAN', '', '41.661538', '-74.817751')),
#   ('12788',
#    ('12788', 'Woodbourne', 'NY', 'SULLIVAN', '', '41.810974', '-74.729403')),
#   ('12811',
#    ('12811', 'Bakers Mills', 'NY', 'WARREN', '', '43.62422', '-74.061201')),
#   ('12827',
#    ('12827', 'Fort Ann', 'NY', 'WASHINGTON', '', '43.443936', '-73.489198')),
#   ('12839',
#    ('12839',
#     'Hudson Falls',
#     'NY',
#     'WASHINGTON',
#     '',
#     '43.203596',
#     '-73.468589')),
#   ('12842',
#    ('12842', 'Indian Lake', 'NY', 'HAMILTON', '', '43.749928', '-74.327593')),
#   ('12845',
#    ('12845', 'Lake George', 'NY', 'WARREN', '', '43.518611', '-73.875462')),
#   ('12855',
#    ('12855', 'North Hudson', 'NY', 'ESSEX', '', '43.970736', '-73.721139')),
#   ('12874',
#    ('12874', 'Silver Bay', 'NY', 'WARREN', '', '43.693173', '-73.505019')),
#   ('12911',
#    ('12911', 'Keeseville', 'NY', 'CLINTON', '', '44.528081', '-73.471946')),
#   ('12923',
#    ('12923', 'Churubusco', 'NY', 'CLINTON', '', '44.916842', '-73.932053')),
#   ('12929',
#    ('12929', 'Dannemora', 'NY', 'CLINTON', '', '44.847709', '-73.582317')),
#   ('12930',
#    ('12930',
#     'Dickinson Center',
#     'NY',
#     'FRANKLIN',
#     '',
#     '44.552725',
#     '-74.317958')),
#   ('12939',
#    ('12939', 'Gabriels', 'NY', 'FRANKLIN', '', '44.552725', '-74.317958')),
#   ('12960', ('12960', 'Moriah', 'NY', 'ESSEX', '', '44.041863', '-73.505265')),
#   ('12961',
#    ('12961', 'Moriah Center', 'NY', 'ESSEX', '', '44.055155', '-73.534677')),
#   ('12966',
#    ('12966', 'North Bangor', 'NY', 'FRANKLIN', '', '44.8532', '-74.419121')),
#   ('12972', ('12972', 'Peru', 'NY', 'CLINTON', '', '44.66607', '-73.569167')),
#   ('12996',
#    ('12996', 'Willsboro', 'NY', 'ESSEX', '', '44.242261', '-73.416202')),
#   ('13020',
#    ('13020',
#     'Apulia Station',
#     'NY',
#     'ONONDAGA',
#     '',
#     '42.823968',
#     '-76.062425')),
#   ('13029',
#    ('13029', 'Brewerton', 'NY', 'ONONDAGA', '', '43.227448', '-76.140648')),
#   ('13031',
#    ('13031', 'Camillus', 'NY', 'ONONDAGA', '', '43.049756', '-76.348012')),
#   ('13035',
#    ('13035', 'Cazenovia', 'NY', 'MADISON', '', '42.939422', '-75.775568')),
#   ('13057',
#    ('13057',
#     'East Syracuse',
#     'NY',
#     'ONONDAGA',
#     '',
#     '43.096216',
#     '-76.047426')),
#   ('13084',
#    ('13084', 'La Fayette', 'NY', 'ONONDAGA', '', '42.891099', '-76.128862')),
#   ('13089',
#    ('13089', 'Liverpool', 'NY', 'ONONDAGA', '', '43.02143', '-76.197701')),
#   ('13093',
#    ('13093', 'Lycoming', 'NY', 'OSWEGO', '', '43.431311', '-76.200448')),
#   ('13107',
#    ('13107', 'Maple View', 'NY', 'OSWEGO', '', '43.457798', '-76.153442')),
#   ('13108',
#    ('13108', 'Marcellus', 'NY', 'ONONDAGA', '', '42.948057', '-76.329799')),
#   ('13144',
#    ('13144', 'Richland', 'NY', 'OSWEGO', '', '43.571095', '-75.972208')),
#   ('13146',
#    ('13146', 'Savannah', 'NY', 'WAYNE', '', '43.099386', '-76.762705')),
#   ('13157',
#    ('13157', 'Sylvan Beach', 'NY', 'ONEIDA', '', '43.209147', '-75.72307')),
#   ('13164',
#    ('13164', 'Warners', 'NY', 'ONONDAGA', '', '43.100588', '-76.321678')),
#   ('13205',
#    ('13205', 'Syracuse', 'NY', 'ONONDAGA', '', '43.006816', '-76.142495')),
#   ('13220',
#    ('13220', 'Syracuse', 'NY', 'ONONDAGA', '', '43.123415', '-76.12823')),
#   ('13224',
#    ('13224', 'Syracuse', 'NY', 'ONONDAGA', '', '43.038366', '-76.099394')),
#   ('13354',
#    ('13354', 'Holland Patent', 'NY', 'ONEIDA', '', '43.273266', '-75.301263')),
#   ('13431',
#    ('13431', 'Poland', 'NY', 'HERKIMER', '', '43.232502', '-75.07288')),
#   ('13457',
#    ('13457', 'Schuyler Lake', 'NY', 'OTSEGO', '', '42.775805', '-75.048502')),
#   ('13477',
#    ('13477', 'Vernon Center', 'NY', 'ONEIDA', '', '43.141536', '-75.530826')),
#   ('13607',
#    ('13607',
#     'Alexandria Bay',
#     'NY',
#     'JEFFERSON',
#     '',
#     '44.074604',
#     '-75.840719')),
#   ('13621',
#    ('13621',
#     'Chase Mills',
#     'NY',
#     'SAINT LAWRENCE',
#     '',
#     '44.845315',
#     '-75.047975')),
#   ('13632',
#    ('13632', 'Depauville', 'NY', 'JEFFERSON', '', '44.139501', '-76.061552')),
#   ('13654',
#    ('13654',
#     'Heuvelton',
#     'NY',
#     'SAINT LAWRENCE',
#     '',
#     '44.616648',
#     '-75.185085')),
#   ('13655',
#    ('13655', 'Hogansburg', 'NY', 'FRANKLIN', '', '44.980232', '-74.647334')),
#   ('13662',
#    ('13662', 'Massena', 'NY', 'SAINT LAWRENCE', '', '44.57026', '-75.152249')),
#   ('13693',
#    ('13693',
#     'Three Mile Bay',
#     'NY',
#     'JEFFERSON',
#     '',
#     '44.029787',
#     '-76.222374')),
#   ('13695',
#    ('13695',
#     'Wanakena',
#     'NY',
#     'SAINT LAWRENCE',
#     '',
#     '44.140791',
#     '-74.912493')),
#   ('13732',
#    ('13732', 'Apalachin', 'NY', 'TIOGA', '', '42.049798', '-76.181009')),
#   ('13750',
#    ('13750', 'Davenport', 'NY', 'DELAWARE', '', '42.444889', '-74.840217')),
#   ('13784',
#    ('13784', 'Harford', 'NY', 'CORTLAND', '', '42.431068', '-76.159312')),
#   ('13806',
#    ('13806', 'Meridale', 'NY', 'DELAWARE', '', '42.183045', '-74.925617')),
#   ('13843',
#    ('13843',
#     'South New Berlin',
#     'NY',
#     'CHENANGO',
#     '',
#     '42.542579',
#     '-75.412243')),
#   ('13847',
#    ('13847', 'Trout Creek', 'NY', 'DELAWARE', '', '42.183045', '-74.925617')),
#   ('13901',
#    ('13901', 'Binghamton', 'NY', 'BROOME', '', '42.165629', '-75.890685')),
#   ('14030', ('14030', 'Chaffee', 'NY', 'ERIE', '', '42.560669', '-78.522178')),
#   ('14035',
#    ('14035', 'Collins Center', 'NY', 'ERIE', '', '42.49064', '-78.849861')),
#   ('14052',
#    ('14052', 'East Aurora', 'NY', 'ERIE', '', '42.768209', '-78.577136')),
#   ('14062',
#    ('14062',
#     'Forestville',
#     'NY',
#     'CHAUTAUQUA',
#     '',
#     '42.441146',
#     '-79.172343')),
#   ('14066',
#    ('14066', 'Gainesville', 'NY', 'WYOMING', '', '42.629014', '-78.19448')),
#   ('14070',
#    ('14070', 'Gowanda', 'NY', 'CATTARAUGUS', '', '42.41994', '-78.954628')),
#   ('14102', ('14102', 'Marilla', 'NY', 'ERIE', '', '42.851099', '-78.547172')),
#   ('14113',
#    ('14113', 'North Java', 'NY', 'WYOMING', '', '42.656199', '-78.340092')),
#   ('14129',
#    ('14129',
#     'Perrysburg',
#     'NY',
#     'CATTARAUGUS',
#     '',
#     '42.472671',
#     '-79.007621')),
#   ('14130', ('14130', 'Pike', 'NY', 'WYOMING', '', '42.543108', '-78.153849')),
#   ('14133',
#    ('14133', 'Sandusky', 'NY', 'CATTARAUGUS', '', '42.489129', '-78.366991')),
#   ('14143',
#    ('14143', 'Stafford', 'NY', 'GENESEE', '', '42.975195', '-78.069868')),
#   ('14150',
#    ('14150', 'Tonawanda', 'NY', 'ERIE', '', '42.99704', '-78.878659')),
#   ('14209', ('14209', 'Buffalo', 'NY', 'ERIE', '', '42.918107', '-78.865857')),
#   ('14218', ('14218', 'Buffalo', 'NY', 'ERIE', '', '42.814558', '-78.807754')),
#   ('14269', ('14269', 'Buffalo', 'NY', 'ERIE', '', '42.768413', '-78.887094')),
#   ('14443',
#    ('14443',
#     'East Bloomfield',
#     'NY',
#     'ONTARIO',
#     '',
#     '42.900966',
#     '-77.42331')),
#   ('14452',
#    ('14452', 'Fancher', 'NY', 'ORLEANS', '', '43.381027', '-78.231338')),
#   ('14453',
#    ('14453', 'Fishers', 'NY', 'ONTARIO', '', '43.010908', '-77.47054')),
#   ('14462',
#    ('14462', 'Groveland', 'NY', 'LIVINGSTON', '', '42.694819', '-77.754628')),
#   ('14467',
#    ('14467', 'Henrietta', 'NY', 'MONROE', '', '43.058863', '-77.558902')),
# ...
#   ('21532',
#    ('21532', 'Frostburg', 'MD', 'ALLEGANY', '', '39.64206', '-78.912502')),
#   ('21610',
#    ('21610', 'Betterton', 'MD', 'KENT', '', '39.366812', '-76.067079')),
#   ('21619',
#    ('21619', 'Chester', 'MD', 'QUEEN ANNES', '', '38.946034', '-76.279172')),
#   ('21638',
#    ('21638',
#     'Grasonville',
#     'MD',
#     'QUEEN ANNES',
#     '',
#     '39.019049',
#     '-76.115897')),
#   ('21649',
#    ('21649', 'Marydel', 'MD', 'CAROLINE', '', '39.106088', '-75.79087')),
#   ('21664',
#    ('21664', 'Secretary', 'MD', 'DORCHESTER', '', '38.600971', '-75.947375')),
#   ('21665',
#    ('21665', 'Sherwood', 'MD', 'TALBOT', '', '38.745387', '-76.326606')),
#   ('21675',
#    ('21675', 'Wingate', 'MD', 'DORCHESTER', '', '38.307394', '-76.106344')),
#   ('21678', ('21678', 'Worton', 'MD', 'KENT', '', '39.308842', '-76.08165')),
#   ('21686',
#    ('21686', 'Ridgely', 'MD', 'CAROLINE', '', '38.88927', '-75.861191')),
#   ('21716',
#    ('21716', 'Brunswick', 'MD', 'FREDERICK', '', '39.317945', '-77.624701')),
#   ('21755',
#    ('21755', 'Jefferson', 'MD', 'FREDERICK', '', '39.353688', '-77.567142')),
#   ('21764',
#    ('21764', 'Linwood', 'MD', 'CARROLL', '', '39.534703', '-77.049302')),
#   ('21767',
#    ('21767',
#     'Maugansville',
#     'MD',
#     'WASHINGTON',
#     '',
#     '39.696761',
#     '-77.746766')),
#   ('21778',
#    ('21778', 'Rocky Ridge', 'MD', 'FREDERICK', '', '39.618999', '-77.335442')),
#   ('21784',
#    ('21784', 'Sykesville', 'MD', 'CARROLL', '', '39.45672', '-76.969601')),
#   ('21792',
#    ('21792', 'Unionville', 'MD', 'FREDERICK', '', '39.469961', '-77.392139')),
#   ('21793',
#    ('21793',
#     'Walkersville',
#     'MD',
#     'FREDERICK',
#     '',
#     '39.491247',
#     '-77.343542')),
#   ('21814',
#    ('21814', 'Bivalve', 'MD', 'WICOMICO', '', '38.388434', '-75.6276')),
#   ('21836',
#    ('21836', 'Manokin', 'MD', 'SOMERSET', '', '38.073294', '-75.734412')),
#   ('21837',
#    ('21837',
#     'Mardela Springs',
#     'MD',
#     'WICOMICO',
#     '',
#     '38.458249',
#     '-75.754804')),
#   ('21865',
#    ('21865', 'Tyaskin', 'MD', 'WICOMICO', '', '38.268914', '-75.790882')),
#   ('21902',
#    ('21902', 'Perry Point', 'MD', 'CECIL', '', '39.552962', '-76.072471')),
#   ('22025',
#    ('22025', 'Delaplane', 'VA', 'PRINCE WILLIAM', '', '38.6', '-77.34')),
#   ('22066',
#    ('22066', 'Great Falls', 'VA', 'FAIRFAX', '', '39.001609', '-77.306416')),
#   ('22116',
#    ('22116', 'Merrifield', 'VA', 'FAIRFAX', '', '38.871469', '-77.234428')),
#   ('22160',
#    ('22160', 'Springfield', 'VA', 'FAIRFAX', '', '38.831813', '-77.288755')),
#   ('22214',
#    ('22214', 'Arlington', 'VA', 'ARLINGTON', '', '38.880811', '-77.11295')),
#   ('22229',
#    ('22229', 'Arlington', 'VA', 'ARLINGTON', '', '38.880811', '-77.11295')),
#   ('22303',
#    ('22303', 'Alexandria', 'VA', 'FAIRFAX', '', '38.791231', '-77.08135')),
#   ('22332',
#    ('22332',
#     'Alexandria',
#     'VA',
#     'ALEXANDRIA CITY',
#     '',
#     '38.803142',
#     '-77.072679')),
#   ('22333',
#    ('22333',
#     'Alexandria',
#     'VA',
#     'ALEXANDRIA CITY',
#     '',
#     '38.815762',
#     '-77.09005')),
#   ('22401',
#    ('22401',
#     'Fredericksburg',
#     'VA',
#     'FREDERICKSBURG CITY',
#     '',
#     '38.295135',
#     '-77.483689')),
#   ('22435',
#    ('22435', 'Callao', 'VA', 'NORTHUMBERLAND', '', '37.961716', '-76.577422')),
#   ('22436', ('22436', 'Caret', 'VA', 'ESSEX', '', '38.024704', '-77.037147')),
#   ('22480',
#    ('22480', 'Irvington', 'VA', 'LANCASTER', '', '37.667319', '-76.404996')),
#   ('22504',
#    ('22504', 'Laneview', 'VA', 'ESSEX', '', '37.76914', '-76.712135')),
#   ('22520',
#    ('22520', 'Montross', 'VA', 'WESTMORELAND', '', '38.111955', '-76.82434')),
#   ('22601',
#    ('22601',
#     'Winchester',
#     'VA',
#     'WINCHESTER CITY',
#     '',
#     '39.169668',
#     '-78.16856')),
#   ('22644',
#    ('22644', 'Maurertown', 'VA', 'SHENANDOAH', '', '38.963523', '-78.548229')),
#   ('22733',
#    ('22733', 'Rapidan', 'VA', 'CULPEPER', '', '38.359195', '-78.060292')),
#   ('22748',
#    ('22748', 'Wolftown', 'VA', 'MADISON', '', '38.372652', '-78.380509')),
#   ('22807',
#    ('22807',
#     'Harrisonburg',
#     'VA',
#     'HARRISONBURG CITY',
#     '',
#     '38.440898',
#     '-78.874173')),
#   ('22830',
#    ('22830', 'Fulks Run', 'VA', 'ROCKINGHAM', '', '38.640083', '-78.940553')),
#   ('22842',
#    ('22842',
#     'Mount Jackson',
#     'VA',
#     'SHENANDOAH',
#     '',
#     '38.785693',
#     '-78.680304')),
#   ('22850',
#    ('22850',
#     'Singers Glen',
#     'VA',
#     'ROCKINGHAM',
#     '',
#     '38.55743',
#     '-78.922657')),
#   ('22907',
#    ('22907',
#     'Charlottesville',
#     'VA',
#     'CHARLOTTESVILLE CITY',
#     '',
#     '38.040101',
#     '-78.485066')),
#   ('22937',
#    ('22937', 'Esmont', 'VA', 'ALBEMARLE', '', '37.82019', '-78.609661')),
#   ('22947',
#    ('22947', 'Keswick', 'VA', 'ALBEMARLE', '', '38.053137', '-78.339571')),
#   ('22972',
#    ('22972', 'Somerset', 'VA', 'ORANGE', '', '38.199692', '-78.239378')),
#   ('22974', ('22974', 'Troy', 'VA', 'FLUVANNA', '', '37.95591', '-78.276599')),
#   ('23001',
#    ('23001', 'Achilles', 'VA', 'GLOUCESTER', '', '37.28822', '-76.426013')),
#   ('23003',
#    ('23003', 'Ark', 'VA', 'GLOUCESTER', '', '37.432335', '-76.601616')),
#   ('23018',
#    ('23018', 'Bena', 'VA', 'GLOUCESTER', '', '37.418242', '-76.508402')),
#   ('23030',
#    ('23030',
#     'Charles City',
#     'VA',
#     'CHARLES CITY',
#     '',
#     '37.354115',
#     '-77.073103')),
#   ('23055',
#    ('23055', 'Fork Union', 'VA', 'FLUVANNA', '', '37.848408', '-78.277393')),
#   ('23060',
#    ('23060', 'Glen Allen', 'VA', 'HENRICO', '', '37.595064', '-77.508719')),
#   ('23079',
#    ('23079', 'Jamaica', 'VA', 'MIDDLESEX', '', '37.644319', '-76.446001')),
#   ('23090',
#    ('23090', 'Lightfoot', 'VA', 'YORK', '', '37.235892', '-76.445567')),
#   ('23103',
#    ('23103',
#     'Manakin Sabot',
#     'VA',
#     'GOOCHLAND',
#     '',
#     '37.663224',
#     '-77.791971')),
#   ('23108',
#    ('23108', 'Mascot', 'VA', 'KING AND QUEEN', '', '37.701823', '-76.916248')),
#   ('23109',
#    ('23109', 'Mathews', 'VA', 'MATHEWS', '', '37.410286', '-76.294103')),
#   ('23113',
#    ('23113',
#     'Midlothian',
#     'VA',
#     'CHESTERFIELD',
#     '',
#     '37.494897',
#     '-77.663061')),
#   ('23125',
#    ('23125', 'New Point', 'VA', 'MATHEWS', '', '37.343785', '-76.287792')),
#   ('23129',
#    ('23129', 'Oilville', 'VA', 'GOOCHLAND', '', '37.701136', '-77.790584')),
#   ('23156',
#    ('23156',
#     'Shacklefords',
#     'VA',
#     'KING AND QUEEN',
#     '',
#     '37.544151',
#     '-76.684306')),
#   ('23161',
#    ('23161',
#     'Stevensville',
#     'VA',
#     'KING AND QUEEN',
#     '',
#     '37.701823',
#     '-76.916248')),
#   ('23181',
#    ('23181',
#     'West Point',
#     'VA',
#     'KING WILLIAM',
#     '',
#     '37.607215',
#     '-76.891642')),
#   ('23183',
#    ('23183',
#     'White Marsh',
#     'VA',
#     'GLOUCESTER',
#     '',
#     '37.363201',
#     '-76.532492')),
#   ('23184',
#    ('23184', 'Wicomico', 'VA', 'GLOUCESTER', '', '37.322121', '-76.53185')),
#   ('23190',
#    ('23190',
#     'Woods Cross Roads',
#     'VA',
#     'GLOUCESTER',
#     '',
#     '37.482039',
#     '-76.636154')),
#   ('23225',
#    ('23225',
#     'Richmond',
#     'VA',
#     'RICHMOND CITY',
#     '',
#     '37.519396',
#     '-77.500757')),
#   ('23229',
#    ('23229', 'Richmond', 'VA', 'HENRICO', '', '37.595695', '-77.570359')),
#   ('23236',
#    ('23236', 'Richmond', 'VA', 'CHESTERFIELD', '', '37.466359', '-77.590818')),
#   ('23238',
#    ('23238', 'Richmond', 'VA', 'GOOCHLAND', '', '37.733844', '-77.888082')),
#   ('23278',
#    ('23278',
#     'Richmond',
#     'VA',
#     'RICHMOND CITY',
#     '',
#     '37.524246',
#     '-77.493157')),
#   ('23289',
#    ('23289', 'Richmond', 'VA', 'HENRICO', '', '37.531296', '-77.416103')),
#   ('23310',
#    ('23310',
#     'Cape Charles',
#     'VA',
#     'NORTHAMPTON',
#     '',
#     '37.259125',
#     '-75.961975')),
#   ('23341',
#    ('23341',
#     'Craddockville',
#     'VA',
#     'ACCOMACK',
#     '',
#     '37.577292',
#     '-75.864607')),
#   ('23424',
#    ('23424', 'Rescue', 'VA', 'ISLE OF WIGHT', '', '36.996881', '-76.564516')),
#   ('23426',
#    ('23426', 'Sanford', 'VA', 'ACCOMACK', '', '37.922894', '-75.678111')),
#   ('23431',
#    ('23431',
#     'Smithfield',
#     'VA',
#     'ISLE OF WIGHT',
#     '',
#     '36.898915',
#     '-76.687745')),
#   ('23434',
#    ('23434', 'Suffolk', 'VA', 'SUFFOLK CITY', '', '36.704592', '-76.636158')),
#   ('23452',
#    ('23452',
#     'Virginia Beach',
#     'VA',
#     'VIRGINIA BEACH CITY',
#     '',
#     '36.846147',
#     '-76.097355')),
#   ('23456',
#    ('23456',
#     'Virginia Beach',
#     'VA',
#     'VIRGINIA BEACH CITY',
#     '',
#     '36.746599',
#     '-76.039092')),
#   ('23459',
#    ('23459',
#     'Virginia Beach',
#     'VA',
#     'VIRGINIA BEACH CITY',
#     '',
#     '36.924496',
#     '-76.018703')),
#   ('23465',
#    ('23465',
#     'Virginia Beach',
#     'VA',
#     'VIRGINIA BEACH CITY',
#     '',
#     '36.851243',
#     '-76.169215')),
#   ('23467',
#    ('23467',
#     'Virginia Beach',
#     'VA',
#     'VIRGINIA BEACH CITY',
#     '',
#     '36.795669',
#     '-76.012628')),
#   ('23471',
#    ('23471',
#     'Virginia Beach',
#     'VA',
#     'VIRGINIA BEACH CITY',
#     '',
#     '36.795669',
#     '-76.012628')),
#   ('23487',
#    ('23487', 'Windsor', 'VA', 'ISLE OF WIGHT', '', '36.845054', '-76.713731')),
#   ('23519',
#    ('23519', 'Norfolk', 'VA', 'NORFOLK CITY', '', '36.931166', '-76.23972')),
#   ('23520',
#    ('23520', 'Norfolk', 'VA', 'NORFOLK CITY', '', '36.931166', '-76.23972')),
#   ('23631',
#    ('23631', 'Hampton', 'VA', 'HAMPTON CITY', '', '37.072658', '-76.38992')),
#   ('23693', ('23693', 'Yorktown', 'VA', 'YORK', '', '37.152812', '-76.44791')),
#   ('23696', ('23696', 'Seaford', 'VA', 'YORK', '', '37.189902', '-76.426469')),
#   ('23708',
#    ('23708',
#     'Portsmouth',
#     'VA',
#     'PORTSMOUTH CITY',
#     '',
#     '36.868553',
#     '-76.355165')),
#   ('23857',
#    ('23857', 'Gasburg', 'VA', 'BRUNSWICK', '', '36.596172', '-77.890727')),
#   ('23868',
#    ('23868',
#     'Lawrenceville',
#     'VA',
#     'BRUNSWICK',
#     '',
#     '36.734246',
#     '-77.813561')),
#   ('23885',
#    ('23885', 'Sutherland', 'VA', 'DINWIDDIE', '', '37.180418', '-77.575347')),
#   ('23888',
#    ('23888', 'Wakefield', 'VA', 'SUSSEX', '', '36.958091', '-77.040206')),
#   ('23927',
#    ('23927',
#     'Clarksville',
#     'VA',
#     'MECKLENBURG',
#     '',
#     '36.65565',
#     '-78.458282')),
#   ('24004',
#    ('24004', 'Roanoke', 'VA', 'ROANOKE CITY', '', '37.274175', '-79.95786')),
#   ('24007',
#    ('24007', 'Roanoke', 'VA', 'ROANOKE CITY', '', '37.274175', '-79.95786')),
#   ('24012',
#    ('24012', 'Roanoke', 'VA', 'ROANOKE CITY', '', '37.30529', '-79.92711')),
#   ('24022',
#    ('24022', 'Roanoke', 'VA', 'ROANOKE CITY', '', '37.278439', '-79.933206')),
#   ('24024',
#    ('24024', 'Roanoke', 'VA', 'ROANOKE CITY', '', '37.274175', '-79.95786')),
#   ('24061',
#    ('24061', 'Blacksburg', 'VA', 'MONTGOMERY', '', '37.179115', '-80.351482')),
#   ('24062',
#    ('24062', 'Blacksburg', 'VA', 'MONTGOMERY', '', '37.174227', '-80.395698')),
#   ('24066',
#    ('24066', 'Buchanan', 'VA', 'BOTETOURT', '', '37.547903', '-79.712321')),
#   ('24079',
#    ('24079', 'Copper Hill', 'VA', 'FLOYD', '', '37.048796', '-80.153614')),
#   ('24092',
#    ('24092', 'Glade Hill', 'VA', 'FRANKLIN', '', '36.985894', '-79.772986')),
#   ('24105',
#    ('24105', 'Indian Valley', 'VA', 'FLOYD', '', '36.90035', '-80.585888')),
#   ('24114',
#    ('24114',
#     'Martinsville',
#     'VA',
#     'MARTINSVILLE CITY',
#     '',
#     '36.679571',
#     '-79.865168')),
#   ('24124',
#    ('24124', 'Narrows', 'VA', 'GILES', '', '37.342026', '-80.762866')),
#   ('24149',
#    ('24149', 'Riner', 'VA', 'MONTGOMERY', '', '37.057894', '-80.436385')),
#   ('24203',
#    ('24203', 'Bristol', 'VA', 'BRISTOL', '', '36.761613', '-81.968712')),
#   ('24205',
#    ('24205',
#     'Bristol Merchandise Return',
#     'VA',
#     'BRISTOL',
#     '',
#     '36.61',
#     '-82.17')),
#   ('24209',
#    ('24209', 'Bristol', 'VA', 'BRISTOL', '', '36.761613', '-81.968712')),
#   ('24210',
#    ('24210', 'Abingdon', 'VA', 'WASHINGTON', '', '36.740217', '-82.026738')),
#   ('24277',
#    ('24277', 'Pennington Gap', 'VA', 'LEE', '', '36.75823', '-83.032536')),
#   ('24289',
#    ('24289', 'Trammel', 'VA', 'DICKENSON', '', '37.130943', '-82.344881')),
#   ('24314', ('24314', 'Bastian', 'VA', 'BLAND', '', '37.127348', '-81.15842')),
#   ('24407',
#    ('24407', 'Staunton', 'VA', 'AUGUSTA', '', '38.179715', '-79.141332')),
#   ('24412', ('24412', 'Bacova', 'VA', 'BATH', '', '38.055311', '-79.746367')),
#   ('24438',
#    ('24438', 'Glen Wilton', 'VA', 'BOTETOURT', '', '37.555083', '-79.786151')),
#   ('24512',
#    ('24512', 'Lynchburg', 'VA', 'CAMPBELL', '', '37.242503', '-79.109789')),
#   ('24520',
#    ('24520', 'Alton', 'VA', 'HALIFAX', '', '36.596827', '-79.043054')),
#   ('24527',
#    ('24527', 'Blairs', 'VA', 'PITTSYLVANIA', '', '36.710176', '-79.3381')),
#   ('24538',
#    ('24538', 'Concord', 'VA', 'CAMPBELL', '', '37.296071', '-78.949355')),
#   ('24556',
#    ('24556', 'Goode', 'VA', 'BEDFORD', '', '37.375464', '-79.403888')),
#   ('24558',
#    ('24558', 'Halifax', 'VA', 'HALIFAX', '', '36.783814', '-78.964257')),
#   ('24820',
#    ('24820', 'Capels', 'WV', 'MCDOWELL', '', '37.375246', '-81.653889')),
#   ('24824',
#    ('24824', 'Coalwood', 'WV', 'MCDOWELL', '', '37.375246', '-81.653889')),
#   ('24870',
#    ('24870', 'Oceana', 'WV', 'WYOMING', '', '37.74071', '-81.583069')),
#   ('24877',
#    ('24877', 'Powhatan', 'WV', 'MCDOWELL', '', '37.375246', '-81.653889')),
#   ('24881',
#    ('24881', 'Roderfield', 'WV', 'MCDOWELL', '', '37.375246', '-81.653889')),
#   ('24943',
#    ('24943',
#     'Grassy Meadows',
#     'WV',
#     'GREENBRIER',
#     '',
#     '37.975595',
#     '-80.426874')),
#   ('24944',
#    ('24944', 'Green Bank', 'WV', 'POCAHONTAS', '', '38.387966', '-79.990585')),
#   ('24986',
#    ('24986',
#     'White Sulphur Springs',
#     'WV',
#     'GREENBRIER',
#     '',
#     '37.782726',
#     '-80.312877')),
#   ('25039',
#    ('25039', 'Cedar Grove', 'WV', 'KANAWHA', '', '38.279199', '-81.59823')),
#   ('25047',
#    ('25047', 'Clothier', 'WV', 'LOGAN', '', '37.833204', '-81.902401')),
#   ('25049',
#    ('25049', 'Comfort', 'WV', 'BOONE', '', '38.126494', '-81.607191')),
#   ('25071',
#    ('25071', 'Elkview', 'WV', 'KANAWHA', '', '38.386942', '-81.450424')),
#   ('25095',
#    ('25095', 'Grimms Landing', 'WV', 'MASON', '', '38.752312', '-81.997278')),
#   ('25106',
#    ('25106', 'Henderson', 'WV', 'MASON', '', '38.833117', '-82.138543')),
#   ('25112',
#    ('25112', 'Institute', 'WV', 'KANAWHA', '', '38.282497', '-81.56514')),
#   ('25133', ('25133', 'Maysel', 'WV', 'CLAY', '', '38.465777', '-81.050662')),
#   ('25134',
#    ('25134', 'Miami', 'WV', 'KANAWHA', '', '38.296818', '-81.554655')),
#   ('25139',
#    ('25139', 'Mount Carbon', 'WV', 'FAYETTE', '', '38.139916', '-81.29309')),
#   ('25140',
#    ('25140', 'Naoma', 'WV', 'RALEIGH', '', '37.877222', '-81.481192')),
#   ('25186',
#    ('25186', 'Smithers', 'WV', 'FAYETTE', '', '38.154338', '-81.278012')),
#   ('25201', ('25201', 'Tad', 'WV', 'KANAWHA', '', '38.296818', '-81.554655')),
#   ('25205', ('25205', 'Uneeda', 'WV', 'BOONE', '', '38.042839', '-81.805265')),
#   ('25248',
#    ('25248', 'Kenna', 'WV', 'JACKSON', '', '38.623155', '-81.621667')),
#   ('25260', ('25260', 'Mason', 'WV', 'MASON', '', '39.011467', '-82.016935')),
#   ('25271',
#    ('25271', 'Ripley', 'WV', 'JACKSON', '', '38.791845', '-81.728065')),
#   ('25283',
#    ('25283', 'Valley Fork', 'WV', 'CLAY', '', '38.465777', '-81.050662')),
#   ('25301',
#    ('25301', 'Charleston', 'WV', 'KANAWHA', '', '38.328948', '-81.605094')),
#   ('25304',
#    ('25304', 'Charleston', 'WV', 'KANAWHA', '', '38.305728', '-81.595903')),
#   ('25305',
#    ('25305', 'Charleston', 'WV', 'KANAWHA', '', '38.335798', '-81.612344')),
#   ('25309',
#    ('25309', 'Charleston', 'WV', 'KANAWHA', '', '38.310767', '-81.756808')),
#   ('25314',
#    ('25314', 'Charleston', 'WV', 'KANAWHA', '', '38.32925', '-81.665927')),
#   ('25331',
#    ('25331', 'Charleston', 'WV', 'KANAWHA', '', '38.296818', '-81.554655')),
#   ('25335',
#    ('25335', 'Charleston', 'WV', 'KANAWHA', '', '38.296818', '-81.554655')),
#   ('25364',
#    ('25364', 'Charleston', 'WV', 'KANAWHA', '', '38.296818', '-81.554655')),
#   ('25429',
#    ('25429',
#     'Kearneysville',
#     'WV',
#     'JEFFERSON',
#     '',
#     '39.349586',
#     '-77.878957')),
#   ('25502',
#    ('25502', 'Apple Grove', 'WV', 'MASON', '', '38.657528', '-82.10679')),
#   ...]]

# %% [markdown]
# ----

# %% [markdown]
# __From Training__

# %%
fileRdd = sc.textFile("hdfs://192.168.93.128:9000/input/all_us_zipcodes.csv")

h = fileRdd.first()

# Keyed RDD, where key is the state code, data[2] is a state code NY, CO
fileRdd = (fileRdd.filter(lambda line: line != header)
                 .map(lambda line: line.strip().split(","))
                 .map(lambda data: (data[2], tuple(data)))
          )

def byStateCode(state):
    if (state == "NY"):
        return 1
    #print("**", state)
    return hash(state)

# we need upto 4 partitions
# by default paritionBy uses portable_hash, now we are overwriting that by passing custom partioner

fileRdd = fileRdd.partitionBy(52, byStateCode)    


print("NumPartitions", fileRdd.getNumPartitions())
fileRdd = fileRdd.mapPartitions(showPartData)

k = fileRdd.collect()
# Out:
# [[1.0, 2.0, 3.0, 1.0, 2.0], [4.0, 5.0, 3.5]]

# %% [markdown]
# ----

# %% [markdown]
# Python's `hash()`, PySpark's `pyspark.rdd.portable_hash()`

# %%
hash('CA'), hash(None)
# Out:
# (3416303064931459562, 8795728541134)

# %%
import os

'PYTHONHASHSEED' in os.environ
# Out:
# True

# %%
os.environ['PYTHONHASHSEED'] = '0'

# %%
os.environ['PYTHONHASHSEED']
# Out:
# '0'

# %%
print(rdd.portable_hash('CA'))
# Out:
# 3416303064931459562
